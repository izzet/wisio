# %%
# %load_ext autoreload

# %%
import sys
import os
sys.path.append(os.path.dirname(os.getcwd()))

import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
warnings.simplefilter(action='ignore', category=UserWarning)

# %%
# %autoreload 2
from vani.analyzer import Analyzer

# %%
cluster_settings = dict(
    dashboard_port=3446,
    local_directory="/var/tmp/dask2",
    log_file="%J.log"
)
dig = Analyzer(debug=True, cluster_settings=cluster_settings)
# Out:
# distributed.http.proxy - INFO - To route to workers diagnostics web server please install jupyter-server-proxy: python -m pip install jupyter-server-proxy
# distributed.scheduler - INFO - Clear task state
# distributed.scheduler - INFO -   Scheduler at: tcp://192.168.66.201:34123
# distributed.scheduler - INFO -   dashboard at:       192.168.66.201:3446
# distributed.nanny - INFO -         Start Nanny at: 'tcp://192.168.66.201:42153'
# distributed.nanny - INFO -         Start Nanny at: 'tcp://192.168.66.201:46481'
# distributed.nanny - INFO -         Start Nanny at: 'tcp://192.168.66.201:39175'
# distributed.nanny - INFO -         Start Nanny at: 'tcp://192.168.66.201:37095'
# distributed.nanny - INFO -         Start Nanny at: 'tcp://192.168.66.201:45469'
# distributed.nanny - INFO -         Start Nanny at: 'tcp://192.168.66.201:35267'
# distributed.nanny - INFO -         Start Nanny at: 'tcp://192.168.66.201:37589'
# distributed.nanny - INFO -         Start Nanny at: 'tcp://192.168.66.201:44369'
# distributed.nanny - INFO -         Start Nanny at: 'tcp://192.168.66.201:42319'
# distributed.nanny - INFO -         Start Nanny at: 'tcp://192.168.66.201:32867'
# distributed.nanny - INFO -         Start Nanny at: 'tcp://192.168.66.201:42395'
# distributed.nanny - INFO -         Start Nanny at: 'tcp://192.168.66.201:44415'
# distributed.nanny - INFO -         Start Nanny at: 'tcp://192.168.66.201:41061'
# distributed.nanny - INFO -         Start Nanny at: 'tcp://192.168.66.201:46871'
# distributed.nanny - INFO -         Start Nanny at: 'tcp://192.168.66.201:34245'
# distributed.nanny - INFO -         Start Nanny at: 'tcp://192.168.66.201:35967'
# distributed.worker - INFO -       Start worker at: tcp://192.168.66.201:44571
# distributed.worker - INFO -       Start worker at: tcp://192.168.66.201:40463
# distributed.worker - INFO -          Listening to: tcp://192.168.66.201:40463
# distributed.worker - INFO -          Listening to: tcp://192.168.66.201:44571
# distributed.worker - INFO -          dashboard at:       192.168.66.201:41097
# distributed.worker - INFO - Waiting to connect to: tcp://192.168.66.201:34123
# distributed.worker - INFO -          dashboard at:       192.168.66.201:37815
# distributed.worker - INFO - -------------------------------------------------
# distributed.worker - INFO -               Threads:                          8
# distributed.worker - INFO - Waiting to connect to: tcp://192.168.66.201:34123
# distributed.worker - INFO -       Local Directory: /var/tmp/dask2/local/dask-worker-space/worker-_es_6fnc
# distributed.worker - INFO - -------------------------------------------------
# distributed.worker - INFO - -------------------------------------------------
# distributed.worker - INFO -       Start worker at: tcp://192.168.66.201:39481
# distributed.worker - INFO -               Threads:                          8
# distributed.worker - INFO -          Listening to: tcp://192.168.66.201:39481
# distributed.worker - INFO -       Local Directory: /var/tmp/dask2/local/dask-worker-space/worker-ip9l40nm
# distributed.worker - INFO -          dashboard at:       192.168.66.201:33503
# distributed.worker - INFO - Waiting to connect to: tcp://192.168.66.201:34123
# distributed.worker - INFO - -------------------------------------------------
# distributed.worker - INFO - -------------------------------------------------
# distributed.worker - INFO -       Start worker at: tcp://192.168.66.201:34211
# distributed.worker - INFO -               Threads:                          8
# distributed.worker - INFO -       Start worker at: tcp://192.168.66.201:35017
# distributed.worker - INFO -       Local Directory: /var/tmp/dask2/local/dask-worker-space/worker-6bxk3uvs
# distributed.worker - INFO -          Listening to: tcp://192.168.66.201:34211
# distributed.worker - INFO -          Listening to: tcp://192.168.66.201:35017
# distributed.worker - INFO - -------------------------------------------------
# distributed.worker - INFO -          dashboard at:       192.168.66.201:44773
# distributed.worker - INFO -          dashboard at:       192.168.66.201:37897
# distributed.worker - INFO - Waiting to connect to: tcp://192.168.66.201:34123
# distributed.worker - INFO - Waiting to connect to: tcp://192.168.66.201:34123
# distributed.worker - INFO - -------------------------------------------------
# distributed.worker - INFO - -------------------------------------------------
# distributed.worker - INFO -               Threads:                          8
# distributed.worker - INFO -       Local Directory: /var/tmp/dask2/local/dask-worker-space/worker-2udshari
# distributed.worker - INFO -               Threads:                          8
# distributed.worker - INFO -       Local Directory: /var/tmp/dask2/local/dask-worker-space/worker-qvv5v1v1
# distributed.worker - INFO - -------------------------------------------------
# distributed.worker - INFO - -------------------------------------------------
# distributed.worker - INFO -       Start worker at: tcp://192.168.66.201:34179
# distributed.worker - INFO -          Listening to: tcp://192.168.66.201:34179
# distributed.worker - INFO -          dashboard at:       192.168.66.201:35001
# distributed.worker - INFO - Waiting to connect to: tcp://192.168.66.201:34123
# distributed.worker - INFO - -------------------------------------------------
# distributed.worker - INFO -               Threads:                          8
# distributed.worker - INFO -       Local Directory: /var/tmp/dask2/local/dask-worker-space/worker-xdep9ow4
# distributed.worker - INFO - -------------------------------------------------
# distributed.worker - INFO -       Start worker at: tcp://192.168.66.201:36449
# distributed.worker - INFO -          Listening to: tcp://192.168.66.201:36449
# distributed.worker - INFO -          dashboard at:       192.168.66.201:45055
# distributed.worker - INFO - Waiting to connect to: tcp://192.168.66.201:34123
# distributed.worker - INFO - -------------------------------------------------
# distributed.worker - INFO -               Threads:                          8
# distributed.worker - INFO -       Local Directory: /var/tmp/dask2/local/dask-worker-space/worker-nnojvq7x
# distributed.worker - INFO - -------------------------------------------------
# distributed.worker - INFO -       Start worker at: tcp://192.168.66.201:36019
# distributed.worker - INFO -          Listening to: tcp://192.168.66.201:36019
# distributed.worker - INFO -          dashboard at:       192.168.66.201:42221
# distributed.worker - INFO - Waiting to connect to: tcp://192.168.66.201:34123
# distributed.worker - INFO - -------------------------------------------------
# distributed.worker - INFO -               Threads:                          8
# distributed.worker - INFO -       Local Directory: /var/tmp/dask2/local/dask-worker-space/worker-696dsh6n
# distributed.worker - INFO - -------------------------------------------------
# distributed.worker - INFO -       Start worker at: tcp://192.168.66.201:36435
# distributed.worker - INFO -          Listening to: tcp://192.168.66.201:36435
# distributed.worker - INFO -          dashboard at:       192.168.66.201:39177
# distributed.worker - INFO - Waiting to connect to: tcp://192.168.66.201:34123
# distributed.worker - INFO - -------------------------------------------------
# distributed.worker - INFO -               Threads:                          8
# distributed.worker - INFO -       Local Directory: /var/tmp/dask2/local/dask-worker-space/worker-c05vazxr
# distributed.worker - INFO - -------------------------------------------------
# distributed.worker - INFO -       Start worker at: tcp://192.168.66.201:38097
# distributed.worker - INFO -          Listening to: tcp://192.168.66.201:38097
# distributed.worker - INFO -          dashboard at:       192.168.66.201:40431
# distributed.worker - INFO - Waiting to connect to: tcp://192.168.66.201:34123
# distributed.worker - INFO - -------------------------------------------------
# distributed.worker - INFO -               Threads:                          8
# distributed.worker - INFO -       Local Directory: /var/tmp/dask2/local/dask-worker-space/worker-egsthokw
# distributed.worker - INFO - -------------------------------------------------
# distributed.worker - INFO -       Start worker at: tcp://192.168.66.201:38945
# distributed.worker - INFO -          Listening to: tcp://192.168.66.201:38945
# distributed.worker - INFO -          dashboard at:       192.168.66.201:34313
# distributed.worker - INFO - Waiting to connect to: tcp://192.168.66.201:34123
# distributed.worker - INFO - -------------------------------------------------
# distributed.worker - INFO -               Threads:                          8
# distributed.worker - INFO -       Local Directory: /var/tmp/dask2/local/dask-worker-space/worker-la9sps0r
# distributed.worker - INFO - -------------------------------------------------
# distributed.worker - INFO -       Start worker at: tcp://192.168.66.201:36421
# distributed.worker - INFO -          Listening to: tcp://192.168.66.201:36421
# distributed.worker - INFO -          dashboard at:       192.168.66.201:36649
# distributed.worker - INFO - Waiting to connect to: tcp://192.168.66.201:34123
# distributed.worker - INFO - -------------------------------------------------
# distributed.worker - INFO -               Threads:                          8
# distributed.worker - INFO -       Local Directory: /var/tmp/dask2/local/dask-worker-space/worker-unlgjlk5
# distributed.worker - INFO - -------------------------------------------------
# distributed.worker - INFO -       Start worker at: tcp://192.168.66.201:35525
# distributed.worker - INFO -          Listening to: tcp://192.168.66.201:35525
# distributed.worker - INFO -          dashboard at:       192.168.66.201:41015
# distributed.worker - INFO - Waiting to connect to: tcp://192.168.66.201:34123
# distributed.worker - INFO - -------------------------------------------------
# distributed.worker - INFO -               Threads:                          8
# distributed.worker - INFO -       Local Directory: /var/tmp/dask2/local/dask-worker-space/worker-29q46jhx
# distributed.worker - INFO - -------------------------------------------------
# distributed.worker - INFO -       Start worker at: tcp://192.168.66.201:42191
# distributed.worker - INFO -          Listening to: tcp://192.168.66.201:42191
# distributed.worker - INFO -          dashboard at:       192.168.66.201:42807
# distributed.worker - INFO - Waiting to connect to: tcp://192.168.66.201:34123
# distributed.worker - INFO - -------------------------------------------------
# distributed.worker - INFO -               Threads:                          8
# distributed.worker - INFO -       Local Directory: /var/tmp/dask2/local/dask-worker-space/worker-x4ys6da8
# distributed.worker - INFO - -------------------------------------------------
# distributed.worker - INFO -       Start worker at: tcp://192.168.66.201:36621
# distributed.worker - INFO -          Listening to: tcp://192.168.66.201:36621
# distributed.worker - INFO -          dashboard at:       192.168.66.201:36331
# distributed.worker - INFO - Waiting to connect to: tcp://192.168.66.201:34123
# distributed.worker - INFO - -------------------------------------------------
# distributed.worker - INFO -               Threads:                          8
# distributed.worker - INFO -       Local Directory: /var/tmp/dask2/local/dask-worker-space/worker-nhutpaza
# distributed.worker - INFO - -------------------------------------------------
# distributed.worker - INFO -       Start worker at: tcp://192.168.66.201:44787
# distributed.worker - INFO -          Listening to: tcp://192.168.66.201:44787
# distributed.worker - INFO -          dashboard at:       192.168.66.201:40737
# distributed.worker - INFO - Waiting to connect to: tcp://192.168.66.201:34123
# distributed.worker - INFO - -------------------------------------------------
# distributed.worker - INFO -               Threads:                          8
# distributed.worker - INFO -       Local Directory: /var/tmp/dask2/local/dask-worker-space/worker-93vepeli
# distributed.worker - INFO - -------------------------------------------------
# distributed.scheduler - INFO - Register worker <WorkerState 'tcp://192.168.66.201:39481', name: 6, status: undefined, memory: 0, processing: 0>
# distributed.scheduler - INFO - Starting worker compute stream, tcp://192.168.66.201:39481
# distributed.core - INFO - Starting established connection
# distributed.worker - INFO -         Registered to: tcp://192.168.66.201:34123
# distributed.worker - INFO - -------------------------------------------------
# distributed.core - INFO - Starting established connection
# distributed.scheduler - INFO - Register worker <WorkerState 'tcp://192.168.66.201:40463', name: 3, status: undefined, memory: 0, processing: 0>
# distributed.scheduler - INFO - Starting worker compute stream, tcp://192.168.66.201:40463
# distributed.worker - INFO -         Registered to: tcp://192.168.66.201:34123
# distributed.worker - INFO - -------------------------------------------------
# distributed.core - INFO - Starting established connection
# distributed.core - INFO - Starting established connection
# distributed.scheduler - INFO - Register worker <WorkerState 'tcp://192.168.66.201:36435', name: 1, status: undefined, memory: 0, processing: 0>
# distributed.scheduler - INFO - Starting worker compute stream, tcp://192.168.66.201:36435
# distributed.worker - INFO -         Registered to: tcp://192.168.66.201:34123
# distributed.core - INFO - Starting established connection
# distributed.worker - INFO - -------------------------------------------------
# distributed.core - INFO - Starting established connection
# distributed.scheduler - INFO - Register worker <WorkerState 'tcp://192.168.66.201:38097', name: 8, status: undefined, memory: 0, processing: 0>
# distributed.scheduler - INFO - Starting worker compute stream, tcp://192.168.66.201:38097
# distributed.worker - INFO -         Registered to: tcp://192.168.66.201:34123
# distributed.worker - INFO - -------------------------------------------------
# distributed.core - INFO - Starting established connection
# distributed.core - INFO - Starting established connection
# distributed.scheduler - INFO - Register worker <WorkerState 'tcp://192.168.66.201:35017', name: 15, status: undefined, memory: 0, processing: 0>
# distributed.scheduler - INFO - Starting worker compute stream, tcp://192.168.66.201:35017
# distributed.worker - INFO -         Registered to: tcp://192.168.66.201:34123
# distributed.core - INFO - Starting established connection
# distributed.worker - INFO - -------------------------------------------------
# distributed.core - INFO - Starting established connection
# distributed.scheduler - INFO - Register worker <WorkerState 'tcp://192.168.66.201:36449', name: 12, status: undefined, memory: 0, processing: 0>
# distributed.scheduler - INFO - Starting worker compute stream, tcp://192.168.66.201:36449
# distributed.core - INFO - Starting established connection
# distributed.worker - INFO -         Registered to: tcp://192.168.66.201:34123
# distributed.worker - INFO - -------------------------------------------------
# distributed.core - INFO - Starting established connection
# distributed.scheduler - INFO - Register worker <WorkerState 'tcp://192.168.66.201:44571', name: 4, status: undefined, memory: 0, processing: 0>
# distributed.scheduler - INFO - Starting worker compute stream, tcp://192.168.66.201:44571
# distributed.core - INFO - Starting established connection
# distributed.worker - INFO -         Registered to: tcp://192.168.66.201:34123
# distributed.worker - INFO - -------------------------------------------------
# distributed.scheduler - INFO - Register worker <WorkerState 'tcp://192.168.66.201:34211', name: 2, status: undefined, memory: 0, processing: 0>
# distributed.core - INFO - Starting established connection
# distributed.scheduler - INFO - Starting worker compute stream, tcp://192.168.66.201:34211
# distributed.worker - INFO -         Registered to: tcp://192.168.66.201:34123
# distributed.core - INFO - Starting established connection
# distributed.worker - INFO - -------------------------------------------------
# distributed.scheduler - INFO - Register worker <WorkerState 'tcp://192.168.66.201:36019', name: 14, status: undefined, memory: 0, processing: 0>
# distributed.core - INFO - Starting established connection
# distributed.scheduler - INFO - Starting worker compute stream, tcp://192.168.66.201:36019
# distributed.core - INFO - Starting established connection
# distributed.worker - INFO -         Registered to: tcp://192.168.66.201:34123
# distributed.worker - INFO - -------------------------------------------------
# distributed.core - INFO - Starting established connection
# distributed.scheduler - INFO - Register worker <WorkerState 'tcp://192.168.66.201:34179', name: 9, status: undefined, memory: 0, processing: 0>
# distributed.scheduler - INFO - Starting worker compute stream, tcp://192.168.66.201:34179
# distributed.core - INFO - Starting established connection
# distributed.worker - INFO -         Registered to: tcp://192.168.66.201:34123
# distributed.worker - INFO - -------------------------------------------------
# distributed.core - INFO - Starting established connection
# distributed.scheduler - INFO - Register worker <WorkerState 'tcp://192.168.66.201:38945', name: 0, status: undefined, memory: 0, processing: 0>
# distributed.scheduler - INFO - Starting worker compute stream, tcp://192.168.66.201:38945
# distributed.worker - INFO -         Registered to: tcp://192.168.66.201:34123
# distributed.worker - INFO - -------------------------------------------------
# distributed.core - INFO - Starting established connection
# distributed.core - INFO - Starting established connection
# distributed.scheduler - INFO - Register worker <WorkerState 'tcp://192.168.66.201:42191', name: 7, status: undefined, memory: 0, processing: 0>
# distributed.scheduler - INFO - Starting worker compute stream, tcp://192.168.66.201:42191
# distributed.core - INFO - Starting established connection
# distributed.worker - INFO -         Registered to: tcp://192.168.66.201:34123
# distributed.worker - INFO - -------------------------------------------------
# distributed.core - INFO - Starting established connection
# distributed.scheduler - INFO - Register worker <WorkerState 'tcp://192.168.66.201:36621', name: 10, status: undefined, memory: 0, processing: 0>
# distributed.scheduler - INFO - Starting worker compute stream, tcp://192.168.66.201:36621
# distributed.core - INFO - Starting established connection
# distributed.worker - INFO -         Registered to: tcp://192.168.66.201:34123
# distributed.worker - INFO - -------------------------------------------------
# distributed.core - INFO - Starting established connection
# distributed.scheduler - INFO - Register worker <WorkerState 'tcp://192.168.66.201:35525', name: 13, status: undefined, memory: 0, processing: 0>
# distributed.scheduler - INFO - Starting worker compute stream, tcp://192.168.66.201:35525
# distributed.worker - INFO -         Registered to: tcp://192.168.66.201:34123
# distributed.worker - INFO - -------------------------------------------------
# distributed.core - INFO - Starting established connection
# distributed.core - INFO - Starting established connection
# distributed.scheduler - INFO - Register worker <WorkerState 'tcp://192.168.66.201:44787', name: 11, status: undefined, memory: 0, processing: 0>
# distributed.scheduler - INFO - Starting worker compute stream, tcp://192.168.66.201:44787
# distributed.worker - INFO -         Registered to: tcp://192.168.66.201:34123
# distributed.worker - INFO - -------------------------------------------------
# distributed.core - INFO - Starting established connection
# distributed.core - INFO - Starting established connection
# distributed.scheduler - INFO - Register worker <WorkerState 'tcp://192.168.66.201:36421', name: 5, status: undefined, memory: 0, processing: 0>
# distributed.scheduler - INFO - Starting worker compute stream, tcp://192.168.66.201:36421
# distributed.worker - INFO -         Registered to: tcp://192.168.66.201:34123
# distributed.core - INFO - Starting established connection
# distributed.worker - INFO - -------------------------------------------------
# distributed.core - INFO - Starting established connection
# Dashboard link: http://192.168.66.201:3446/status
# Dashboard link: http://192.168.66.201:3447/status
# #!/usr/bin/env bash
#
# #BSUB -J dask-worker
# #BSUB -G asccasc
# #BSUB -q pdebug
# #BSUB -W 120
# #BSUB -o .digio/worker_logs/%J.log
# #BSUB -e .digio/worker_logs/%J.log
#
# /usr/WS2/iopp/projects/vani-analysis-tool/virenv-lassen/bin/python -m distributed.cli.dask_worker tcp://192.168.66.201:46339 --nthreads 1 --nprocs 16 --memory-limit 93.13GiB --name dummy-name --nanny --death-timeout 7200 --local-directory /var/tmp/dask2/tmid
#
# Dashboard link: http://192.168.66.201:3448/status
# #!/usr/bin/env bash
#
# #BSUB -J dask-worker
# #BSUB -G asccasc
# #BSUB -q pdebug
# #BSUB -W 120
# #BSUB -o .digio/worker_logs/%J.log
# #BSUB -e .digio/worker_logs/%J.log
#
# /usr/WS2/iopp/projects/vani-analysis-tool/virenv-lassen/bin/python -m distributed.cli.dask_worker tcp://192.168.66.201:40435 --nthreads 1 --nprocs 16 --memory-limit 93.13GiB --name dummy-name --nanny --death-timeout 7200 --local-directory /var/tmp/dask2/proc_id
#
# Dashboard link: http://192.168.66.201:3449/status
# #!/usr/bin/env bash
#
# #BSUB -J dask-worker
# #BSUB -G asccasc
# #BSUB -q pdebug
# #BSUB -W 120
# #BSUB -o .digio/worker_logs/%J.log
# #BSUB -e .digio/worker_logs/%J.log
#
# /usr/WS2/iopp/projects/vani-analysis-tool/virenv-lassen/bin/python -m distributed.cli.dask_worker tcp://192.168.66.201:40567 --nthreads 1 --nprocs 16 --memory-limit 93.13GiB --name dummy-name --nanny --death-timeout 7200 --local-directory /var/tmp/dask2/file_id
#
# <Client: 'tcp://192.168.66.201:34123' processes=16 threads=128>
# <Client: 'tcp://192.168.66.201:46339' processes=0 threads=0, memory=0 B>
# <Client: 'tcp://192.168.66.201:40435' processes=0 threads=0, memory=0 B>
# <Client: 'tcp://192.168.66.201:40567' processes=0 threads=0, memory=0 B>

# %%
# log_dir = "/p/gpfs1/iopp/recorder_app_logs/genome_pegasus/nodes-32/_parquet"
# log_dir = "/p/gpfs1/iopp/recorder_app_logs/hacc/nodes-32/workflow-0/_parquet"
log_dir = "/p/gpfs1/iopp/recorder_app_logs/cm1/nodes-32/workflow-4/_parquet"
# log_dir = "/p/gpfs1/iopp/recorder_app_logs/lbann-jag/nodes-32/_parquet"

ret = dig.analyze_parquet_logs(log_dir, depth=10, persist_stats=True, stats_file_prefix="cm1_")

ret
# Out:
# tmid 6526422 range(0, 6683055996, 6526422)
# proc_id 81856 range(5117778030848174740, 5117778030931995284, 81856)
# file_id 17992755447750160 range(-9210576409139474804, 9214005169356689175, 17992755447750160)
