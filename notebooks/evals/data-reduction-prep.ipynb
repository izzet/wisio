# %%
# %load_ext autoreload
# %load_ext autotime
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# The autotime extension is already loaded. To reload it, use:
#   %reload_ext autotime
# time: 2.62 ms (started: 2023-06-12 10:16:22 -07:00)

# %%
# log_dir = "/p/vast1/iopp/recorder_app_logs/cm1/nodes-32/workflow-4/_parquet"
# log_dir = "/p/vast1/iopp/recorder_app_logs/hacc/nodes-32/workflow-0/_parquet"
log_dir = "/p/vast1/iopp/recorder_app_logs/montage/nodes-32/_parquet"
# log_dir = "/p/gpfs1/iopp/recorder_app_logs/genome_pegasus/nodes-32/_parquet"
# log_dir = "/p/gpfs1/iopp/recorder_app_logs/lbann-jag/nodes-32/_parquet"
# Out:
# time: 929 µs (started: 2023-06-12 10:16:23 -07:00)

# %%
# !ls -lh {log_dir}
# Out:
# total 218M
# -rw------- 1 izzet iopp  15M Mar 11 16:12 0_0.parquet
# -rw------- 1 izzet iopp  15M Mar 11 16:12 1_0.parquet
# -rw------- 1 izzet iopp  36M Mar 11 16:12 2_0.parquet
# -rw------- 1 izzet iopp  30M Mar 11 16:11 3_0.parquet
# -rw------- 1 izzet iopp 223K Mar 11 16:12 3_1.parquet
# -rw------- 1 izzet iopp 9.6M Mar 11 16:12 4_0.parquet
# -rw------- 1 izzet iopp  11M Mar 11 16:12 5_0.parquet
# -rw------- 1 izzet iopp  29M Mar 11 16:11 6_0.parquet
# -rw------- 1 izzet iopp  12M Mar 11 16:12 6_1.parquet
# -rw------- 1 izzet iopp  28M Mar 11 16:09 7_0.parquet
# -rw------- 1 izzet iopp  29M Mar 11 16:11 7_1.parquet
# -rw------- 1 izzet iopp 9.0M Mar 11 16:12 7_2.parquet
# drwxr-sr-x 2 izzet iopp 4.0K Mar 12 17:52 bottlenecks
# drwx--S--- 2 izzet iopp 4.0K May 31 11:18 checkpoints
# -rw------- 1 izzet iopp  127 Mar 11 16:12 global.json
# time: 292 ms (started: 2023-06-12 10:16:24 -07:00)

# %%
import dask.dataframe as dd
import numpy as np
import pandas as pd
# Out:
# time: 973 µs (started: 2023-06-12 10:16:25 -07:00)

# %%
sample_df_1m = pd.read_parquet(f"{log_dir}/3_0.parquet")
sample_df_1m = sample_df_1m[:1_000_000]
sample_df_1m
# Out:
#           index   proc  rank  thread_id  cat  io_cat    tstart      tend  \
# 0             1  95463     0     313232    0       3  0.114543  0.114552
# 1             2  95463     0     313232    0       3  0.114649  0.114659
# 2             3  95463     0     313232    0       3  0.114732  0.114742
# 3             4  95463     0     313232    0       3  0.115139  0.115156
# 4             5  95463     0     313232    0       1  0.115227  0.115244
# ...         ...    ...   ...        ...  ...     ...       ...       ...
# 999995   999996  41422    12     317888    0       1  3.327976  3.327976
# 999996   999997  41422    12     317888    0       1  3.327979  3.327979
# 999997   999998  41422    12     317888    0       1  3.327984  3.327984
# 999998   999999  41422    12     317888    0       1  3.327987  3.327987
# 999999  1000000  41422    12     317888    0       2  3.328068  3.328152
#
#           func_id  level  ...        app  \
# 0       __xstat64      0  ...  mProjExec
# 1       __xstat64      0  ...  mProjExec
# 2       __xstat64      0  ...  mProjExec
# 3         fopen64      0  ...  mProjExec
# 4           fread      0  ...  mProjExec
# ...           ...    ...  ...        ...
# 999995      fread      0  ...    mAddMPI
# 999996      fread      0  ...    mAddMPI
# 999997      fread      0  ...    mAddMPI
# 999998      fread      0  ...    mAddMPI
# 999999     fwrite      0  ...    mAddMPI
#
#                                        proc_name  \
# 0       mProjExec#lassen375#95463#35184372402064
# 1       mProjExec#lassen375#95463#35184372402064
# 2       mProjExec#lassen375#95463#35184372402064
# 3       mProjExec#lassen375#95463#35184372402064
# 4       mProjExec#lassen375#95463#35184372402064
# ...                                          ...
# 999995    mAddMPI#lassen246#41422#35184372406720
# 999996    mAddMPI#lassen246#41422#35184372406720
# 999997    mAddMPI#lassen246#41422#35184372406720
# 999998    mAddMPI#lassen246#41422#35184372406720
# 999999    mAddMPI#lassen246#41422#35184372406720
#
#                                                 file_name  size  acc_pat  \
# 0                   /p/gpfs1/iopp/temp/montage/2854964/15     0        0
# 1       /p/gpfs1/iopp/temp/montage/2854964/15/run/Kima...     0        0
# 2       /p/gpfs1/iopp/temp/montage/2854964/15/run/Kpro...     0        0
# 3       /p/gpfs1/iopp/temp/montage/2854964/15/run/Ktem...     0        0
# 4       /p/gpfs1/iopp/temp/montage/2854964/15/run/Ktem...     2        0
# ...                                                   ...   ...      ...
# 999995  /p/gpfs1/iopp/temp/montage/2854964/30/run/Kpro...  2880        0
# 999996  /p/gpfs1/iopp/temp/montage/2854964/30/run/Kpro...  2880        0
# 999997  /p/gpfs1/iopp/temp/montage/2854964/30/run/Kpro...  2880        0
# 999998  /p/gpfs1/iopp/temp/montage/2854964/30/run/Kpro...  2880        0
# 999999  /p/gpfs1/iopp/temp/montage/2854964/30/run/ngc3...  7512        0
#
#         bandwidth  duration      tmid              file_id  \
# 0        0.000000  0.000009   1145474  1571755610889588620
# 1        0.000000  0.000010   1146539  7707285561233204775
# 2        0.000000  0.000010   1147368  7707285563452454344
# 3        0.000000  0.000017   1151472  7707285562318698692
# 4        0.110892  0.000017   1152351  7707285562318698692
# ...           ...       ...       ...                  ...
# 999995   0.000000  0.000000  33279755  3398535317841814911
# 999996   0.000000  0.000000  33279785  3398535317841814911
# 999997   0.000000  0.000000  33279844  3398535315672720268
# 999998   0.000000  0.000000  33279874  3398535315672720268
# 999999  85.184319  0.000084  33281102  7662249567266718920
#
#                     proc_id
# 0      -5153770159769860204
# 1      -5153770159769860204
# 2      -5153770159769860204
# 3      -5153770159769860204
# 4      -5153770159769860204
# ...                     ...
# 999995  8238577613880089028
# 999996  8238577613880089028
# 999997  8238577613880089028
# 999998  8238577613880089028
# 999999  8238577613880089028
#
# [1000000 rows x 21 columns]
# time: 1.16 s (started: 2023-06-12 10:16:27 -07:00)

# %% [markdown]
# ### Pandas - 1m Records

# %%
sample_df_1m.to_parquet('../tmp/eval-samples/data-reduction-1m.parquet')

# %%
pd.concat([sample_df_1m]*10, ignore_index=True)
# Out:
#            index   proc  rank  thread_id  cat  io_cat    tstart      tend  \
# 0              1  95463     0     313232    0       3  0.114543  0.114552
# 1              2  95463     0     313232    0       3  0.114649  0.114659
# 2              3  95463     0     313232    0       3  0.114732  0.114742
# 3              4  95463     0     313232    0       3  0.115139  0.115156
# 4              5  95463     0     313232    0       1  0.115227  0.115244
# ...          ...    ...   ...        ...  ...     ...       ...       ...
# 9999995   999996  41422    12     317888    0       1  3.327976  3.327976
# 9999996   999997  41422    12     317888    0       1  3.327979  3.327979
# 9999997   999998  41422    12     317888    0       1  3.327984  3.327984
# 9999998   999999  41422    12     317888    0       1  3.327987  3.327987
# 9999999  1000000  41422    12     317888    0       2  3.328068  3.328152
#
#            func_id  level  ...        app  \
# 0        __xstat64      0  ...  mProjExec
# 1        __xstat64      0  ...  mProjExec
# 2        __xstat64      0  ...  mProjExec
# 3          fopen64      0  ...  mProjExec
# 4            fread      0  ...  mProjExec
# ...            ...    ...  ...        ...
# 9999995      fread      0  ...    mAddMPI
# 9999996      fread      0  ...    mAddMPI
# 9999997      fread      0  ...    mAddMPI
# 9999998      fread      0  ...    mAddMPI
# 9999999     fwrite      0  ...    mAddMPI
#
#                                         proc_name  \
# 0        mProjExec#lassen375#95463#35184372402064
# 1        mProjExec#lassen375#95463#35184372402064
# 2        mProjExec#lassen375#95463#35184372402064
# 3        mProjExec#lassen375#95463#35184372402064
# 4        mProjExec#lassen375#95463#35184372402064
# ...                                           ...
# 9999995    mAddMPI#lassen246#41422#35184372406720
# 9999996    mAddMPI#lassen246#41422#35184372406720
# 9999997    mAddMPI#lassen246#41422#35184372406720
# 9999998    mAddMPI#lassen246#41422#35184372406720
# 9999999    mAddMPI#lassen246#41422#35184372406720
#
#                                                  file_name  size  acc_pat  \
# 0                    /p/gpfs1/iopp/temp/montage/2854964/15     0        0
# 1        /p/gpfs1/iopp/temp/montage/2854964/15/run/Kima...     0        0
# 2        /p/gpfs1/iopp/temp/montage/2854964/15/run/Kpro...     0        0
# 3        /p/gpfs1/iopp/temp/montage/2854964/15/run/Ktem...     0        0
# 4        /p/gpfs1/iopp/temp/montage/2854964/15/run/Ktem...     2        0
# ...                                                    ...   ...      ...
# 9999995  /p/gpfs1/iopp/temp/montage/2854964/30/run/Kpro...  2880        0
# 9999996  /p/gpfs1/iopp/temp/montage/2854964/30/run/Kpro...  2880        0
# 9999997  /p/gpfs1/iopp/temp/montage/2854964/30/run/Kpro...  2880        0
# 9999998  /p/gpfs1/iopp/temp/montage/2854964/30/run/Kpro...  2880        0
# 9999999  /p/gpfs1/iopp/temp/montage/2854964/30/run/ngc3...  7512        0
#
#          bandwidth  duration      tmid              file_id  \
# 0         0.000000  0.000009   1145474  1571755610889588620
# 1         0.000000  0.000010   1146539  7707285561233204775
# 2         0.000000  0.000010   1147368  7707285563452454344
# 3         0.000000  0.000017   1151472  7707285562318698692
# 4         0.110892  0.000017   1152351  7707285562318698692
# ...            ...       ...       ...                  ...
# 9999995   0.000000  0.000000  33279755  3398535317841814911
# 9999996   0.000000  0.000000  33279785  3398535317841814911
# 9999997   0.000000  0.000000  33279844  3398535315672720268
# 9999998   0.000000  0.000000  33279874  3398535315672720268
# 9999999  85.184319  0.000084  33281102  7662249567266718920
#
#                      proc_id
# 0       -5153770159769860204
# 1       -5153770159769860204
# 2       -5153770159769860204
# 3       -5153770159769860204
# 4       -5153770159769860204
# ...                      ...
# 9999995  8238577613880089028
# 9999996  8238577613880089028
# 9999997  8238577613880089028
# 9999998  8238577613880089028
# 9999999  8238577613880089028
#
# [10000000 rows x 21 columns]
# time: 25.2 s (started: 2023-06-12 12:59:03 -07:00)

# %%
sample_df_1m = pd.read_parquet('../tmp/eval-samples/data-reduction-1m-pandas/full.parquet')
sample_df_1m
# Out:
#           index   proc  rank  thread_id  cat  io_cat    tstart      tend  \
# 0             1  95463     0     313232    0       3  0.114543  0.114552
# 1             2  95463     0     313232    0       3  0.114649  0.114659
# 2             3  95463     0     313232    0       3  0.114732  0.114742
# 3             4  95463     0     313232    0       3  0.115139  0.115156
# 4             5  95463     0     313232    0       1  0.115227  0.115244
# ...         ...    ...   ...        ...  ...     ...       ...       ...
# 999995   999996  41422    12     317888    0       1  3.327976  3.327976
# 999996   999997  41422    12     317888    0       1  3.327979  3.327979
# 999997   999998  41422    12     317888    0       1  3.327984  3.327984
# 999998   999999  41422    12     317888    0       1  3.327987  3.327987
# 999999  1000000  41422    12     317888    0       2  3.328068  3.328152
#
#           func_id  level  ...        app  \
# 0       __xstat64      0  ...  mProjExec
# 1       __xstat64      0  ...  mProjExec
# 2       __xstat64      0  ...  mProjExec
# 3         fopen64      0  ...  mProjExec
# 4           fread      0  ...  mProjExec
# ...           ...    ...  ...        ...
# 999995      fread      0  ...    mAddMPI
# 999996      fread      0  ...    mAddMPI
# 999997      fread      0  ...    mAddMPI
# 999998      fread      0  ...    mAddMPI
# 999999     fwrite      0  ...    mAddMPI
#
#                                        proc_name  \
# 0       mProjExec#lassen375#95463#35184372402064
# 1       mProjExec#lassen375#95463#35184372402064
# 2       mProjExec#lassen375#95463#35184372402064
# 3       mProjExec#lassen375#95463#35184372402064
# 4       mProjExec#lassen375#95463#35184372402064
# ...                                          ...
# 999995    mAddMPI#lassen246#41422#35184372406720
# 999996    mAddMPI#lassen246#41422#35184372406720
# 999997    mAddMPI#lassen246#41422#35184372406720
# 999998    mAddMPI#lassen246#41422#35184372406720
# 999999    mAddMPI#lassen246#41422#35184372406720
#
#                                                 file_name  size  acc_pat  \
# 0                   /p/gpfs1/iopp/temp/montage/2854964/15     0        0
# 1       /p/gpfs1/iopp/temp/montage/2854964/15/run/Kima...     0        0
# 2       /p/gpfs1/iopp/temp/montage/2854964/15/run/Kpro...     0        0
# 3       /p/gpfs1/iopp/temp/montage/2854964/15/run/Ktem...     0        0
# 4       /p/gpfs1/iopp/temp/montage/2854964/15/run/Ktem...     2        0
# ...                                                   ...   ...      ...
# 999995  /p/gpfs1/iopp/temp/montage/2854964/30/run/Kpro...  2880        0
# 999996  /p/gpfs1/iopp/temp/montage/2854964/30/run/Kpro...  2880        0
# 999997  /p/gpfs1/iopp/temp/montage/2854964/30/run/Kpro...  2880        0
# 999998  /p/gpfs1/iopp/temp/montage/2854964/30/run/Kpro...  2880        0
# 999999  /p/gpfs1/iopp/temp/montage/2854964/30/run/ngc3...  7512        0
#
#         bandwidth  duration      tmid              file_id  \
# 0        0.000000  0.000009   1145474  1571755610889588620
# 1        0.000000  0.000010   1146539  7707285561233204775
# 2        0.000000  0.000010   1147368  7707285563452454344
# 3        0.000000  0.000017   1151472  7707285562318698692
# 4        0.110892  0.000017   1152351  7707285562318698692
# ...           ...       ...       ...                  ...
# 999995   0.000000  0.000000  33279755  3398535317841814911
# 999996   0.000000  0.000000  33279785  3398535317841814911
# 999997   0.000000  0.000000  33279844  3398535315672720268
# 999998   0.000000  0.000000  33279874  3398535315672720268
# 999999  85.184319  0.000084  33281102  7662249567266718920
#
#                     proc_id
# 0      -5153770159769860204
# 1      -5153770159769860204
# 2      -5153770159769860204
# 3      -5153770159769860204
# 4      -5153770159769860204
# ...                     ...
# 999995  8238577613880089028
# 999996  8238577613880089028
# 999997  8238577613880089028
# 999998  8238577613880089028
# 999999  8238577613880089028
#
# [1000000 rows x 21 columns]
# time: 1.46 s (started: 2023-06-12 10:55:33 -07:00)

# %% [markdown]
# ### Pandas - 5m Records

# %%
pd.concat([sample_df_1m]*5, ignore_index=True).to_parquet('../tmp/eval-samples/data-reduction-5m-pandas/full.parquet')
# Out:
# ---------------------------------------------------------------------------
# OverflowError                             Traceback (most recent call last)
# OverflowError: value too large to convert to int
# Exception ignored in: 'fastparquet.cencoding.write_thrift'
# Traceback (most recent call last):
#   File "/g/g92/izzet/projects/vani-analysis-tool/venv-quartz2/lib/python3.9/site-packages/fastparquet/writer.py", line 1499, in write_thrift
#     return f.write(obj.to_bytes())
# OverflowError: value too large to convert to int
# time: 51.9 s (started: 2023-06-12 13:00:31 -07:00)

# %%
sample_df_5m = pd.read_parquet('../tmp/eval-samples/data-reduction-5m-pandas/full.parquet')
sample_df_5m
# Out:
#            index   proc  rank  thread_id  cat  io_cat    tstart      tend  \
# 0              1  95463     0     313232    0       3  0.114543  0.114552
# 1              2  95463     0     313232    0       3  0.114649  0.114659
# 2              3  95463     0     313232    0       3  0.114732  0.114742
# 3              4  95463     0     313232    0       3  0.115139  0.115156
# 4              5  95463     0     313232    0       1  0.115227  0.115244
# ...          ...    ...   ...        ...  ...     ...       ...       ...
# 4999995   999996  41422    12     317888    0       1  3.327976  3.327976
# 4999996   999997  41422    12     317888    0       1  3.327979  3.327979
# 4999997   999998  41422    12     317888    0       1  3.327984  3.327984
# 4999998   999999  41422    12     317888    0       1  3.327987  3.327987
# 4999999  1000000  41422    12     317888    0       2  3.328068  3.328152
#
#            func_id  level  ...        app  \
# 0        __xstat64      0  ...  mProjExec
# 1        __xstat64      0  ...  mProjExec
# 2        __xstat64      0  ...  mProjExec
# 3          fopen64      0  ...  mProjExec
# 4            fread      0  ...  mProjExec
# ...            ...    ...  ...        ...
# 4999995      fread      0  ...    mAddMPI
# 4999996      fread      0  ...    mAddMPI
# 4999997      fread      0  ...    mAddMPI
# 4999998      fread      0  ...    mAddMPI
# 4999999     fwrite      0  ...    mAddMPI
#
#                                         proc_name  \
# 0        mProjExec#lassen375#95463#35184372402064
# 1        mProjExec#lassen375#95463#35184372402064
# 2        mProjExec#lassen375#95463#35184372402064
# 3        mProjExec#lassen375#95463#35184372402064
# 4        mProjExec#lassen375#95463#35184372402064
# ...                                           ...
# 4999995    mAddMPI#lassen246#41422#35184372406720
# 4999996    mAddMPI#lassen246#41422#35184372406720
# 4999997    mAddMPI#lassen246#41422#35184372406720
# 4999998    mAddMPI#lassen246#41422#35184372406720
# 4999999    mAddMPI#lassen246#41422#35184372406720
#
#                                                  file_name  size  acc_pat  \
# 0                    /p/gpfs1/iopp/temp/montage/2854964/15     0        0
# 1        /p/gpfs1/iopp/temp/montage/2854964/15/run/Kima...     0        0
# 2        /p/gpfs1/iopp/temp/montage/2854964/15/run/Kpro...     0        0
# 3        /p/gpfs1/iopp/temp/montage/2854964/15/run/Ktem...     0        0
# 4        /p/gpfs1/iopp/temp/montage/2854964/15/run/Ktem...     2        0
# ...                                                    ...   ...      ...
# 4999995  /p/gpfs1/iopp/temp/montage/2854964/30/run/Kpro...  2880        0
# 4999996  /p/gpfs1/iopp/temp/montage/2854964/30/run/Kpro...  2880        0
# 4999997  /p/gpfs1/iopp/temp/montage/2854964/30/run/Kpro...  2880        0
# 4999998  /p/gpfs1/iopp/temp/montage/2854964/30/run/Kpro...  2880        0
# 4999999  /p/gpfs1/iopp/temp/montage/2854964/30/run/ngc3...  7512        0
#
#          bandwidth  duration      tmid              file_id  \
# 0         0.000000  0.000009   1145474  1571755610889588620
# 1         0.000000  0.000010   1146539  7707285561233204775
# 2         0.000000  0.000010   1147368  7707285563452454344
# 3         0.000000  0.000017   1151472  7707285562318698692
# 4         0.110892  0.000017   1152351  7707285562318698692
# ...            ...       ...       ...                  ...
# 4999995   0.000000  0.000000  33279755  3398535317841814911
# 4999996   0.000000  0.000000  33279785  3398535317841814911
# 4999997   0.000000  0.000000  33279844  3398535315672720268
# 4999998   0.000000  0.000000  33279874  3398535315672720268
# 4999999  85.184319  0.000084  33281102  7662249567266718920
#
#                      proc_id
# 0       -5153770159769860204
# 1       -5153770159769860204
# 2       -5153770159769860204
# 3       -5153770159769860204
# 4       -5153770159769860204
# ...                      ...
# 4999995  8238577613880089028
# 4999996  8238577613880089028
# 4999997  8238577613880089028
# 4999998  8238577613880089028
# 4999999  8238577613880089028
#
# [5000000 rows x 21 columns]
# time: 19.4 s (started: 2023-06-12 10:55:36 -07:00)

# %%
sample_ddf_1m = dd.read_parquet('../tmp/eval-samples/data-reduction-1m-pandas/data-reduction-1m.parquet')
sample_ddf_1m
# Out:
# Dask DataFrame Structure:
#                index   proc   rank thread_id    cat io_cat   tstart     tend func_id  level hostname     app proc_name file_name   size acc_pat bandwidth duration   tmid file_id proc_id
# npartitions=1
#                int64  int64  int32     int32  int32  int32  float32  float32  object  int32   object  object    object    object  int64   int32   float32  float32  int64   int64   int64
#                  ...    ...    ...       ...    ...    ...      ...      ...     ...    ...      ...     ...       ...       ...    ...     ...       ...      ...    ...     ...     ...
# Dask Name: read-parquet, 1 tasks
# time: 57.5 ms (started: 2023-06-12 10:10:01 -07:00)

# %% [markdown]
# ### Dask - 1m Records

# %%
sample_ddf_1m \
    .repartition('100MB') \
    .to_parquet('../tmp/eval-samples/data-reduction-1m-dask')
# Out:
# (None,)
# time: 6.47 s (started: 2023-06-12 10:10:56 -07:00)

# %%
sample_ddf_1m = dd.read_parquet('../tmp/eval-samples/data-reduction-1m-dask/*.parquet')
sample_ddf_1m
# Out:
# Dask DataFrame Structure:
#                index   proc   rank thread_id    cat io_cat   tstart     tend func_id  level hostname     app proc_name file_name   size acc_pat bandwidth duration   tmid file_id proc_id
# npartitions=6
# 0              int64  int64  int32     int32  int32  int32  float32  float32  object  int32   object  object    object    object  int64   int32   float32  float32  int64   int64   int64
# 166666           ...    ...    ...       ...    ...    ...      ...      ...     ...    ...      ...     ...       ...       ...    ...     ...       ...      ...    ...     ...     ...
# ...              ...    ...    ...       ...    ...    ...      ...      ...     ...    ...      ...     ...       ...       ...    ...     ...       ...      ...    ...     ...     ...
# 833333           ...    ...    ...       ...    ...    ...      ...      ...     ...    ...      ...     ...       ...       ...    ...     ...       ...      ...    ...     ...     ...
# 999999           ...    ...    ...       ...    ...    ...      ...      ...     ...    ...      ...     ...       ...       ...    ...     ...       ...      ...    ...     ...     ...
# Dask Name: read-parquet, 6 tasks
# time: 172 ms (started: 2023-06-12 10:11:07 -07:00)

# %% [markdown]
# ### Dask - 5m Records

# %%
sample_ddf_5m = dd.read_parquet('../tmp/eval-samples/data-reduction-5m-pandas/full.parquet')
sample_ddf_5m
# Out:
# Dask DataFrame Structure:
#                index   proc   rank thread_id    cat io_cat   tstart     tend func_id  level hostname     app proc_name file_name   size acc_pat bandwidth duration   tmid file_id proc_id
# npartitions=1
#                int64  int64  int32     int32  int32  int32  float32  float32  object  int32   object  object    object    object  int64   int32   float32  float32  int64   int64   int64
#                  ...    ...    ...       ...    ...    ...      ...      ...     ...    ...      ...     ...       ...       ...    ...     ...       ...      ...    ...     ...     ...
# Dask Name: read-parquet, 1 tasks
# time: 47.8 ms (started: 2023-06-12 10:56:16 -07:00)

# %%
sample_ddf_5m \
    .repartition('100MB') \
    .to_parquet('../tmp/eval-samples/data-reduction-5m-dask')
# Out:
# (None,)
# time: 42.5 s (started: 2023-06-12 10:56:34 -07:00)

# %%
import json

with open('../tmp/eval-samples/data-reduction-1m-dask/global.json', 'w') as f:
    global_json = {
        'file_id': [0,1],
        'proc_id': [0,1],
        'tmid':[0,241747494]
    }
    json.dump(global_json, f)
# Out:
# time: 3.24 ms (started: 2023-06-11 18:28:34 -07:00)

# %%
# !cat {log_dir}/global.json
# Out:
# {"file_id":[113104469769545699,8946970060350424228],"proc_id":[-7874823657267864124,8238629349086124484],"tmid":[0,1752590553]}time: 735 ms (started: 2023-06-12 10:57:49 -07:00)

# %%
# !du -h ../tmp/eval-samples
# Out:
# 1.3G	../tmp/eval-samples/data-reduction-5m-dask
# 30M	../tmp/eval-samples/data-reduction-1m-pandas
# 764K	../tmp/eval-samples/data-reduction-1m-dask/checkpoints/_main_view
# 724K	../tmp/eval-samples/data-reduction-1m-dask/checkpoints/file_name
# 1.1M	../tmp/eval-samples/data-reduction-1m-dask/checkpoints/app_name
# 1.1M	../tmp/eval-samples/data-reduction-1m-dask/checkpoints/node_name
# 1.1M	../tmp/eval-samples/data-reduction-1m-dask/checkpoints/rank
# 1.1M	../tmp/eval-samples/data-reduction-1m-dask/checkpoints/file_dir
# 1.1M	../tmp/eval-samples/data-reduction-1m-dask/checkpoints/file_regex
# 6.7M	../tmp/eval-samples/data-reduction-1m-dask/checkpoints
# 262M	../tmp/eval-samples/data-reduction-1m-dask
# 146M	../tmp/eval-samples/data-reduction-5m-pandas
# 1.7G	../tmp/eval-samples
# time: 748 ms (started: 2023-06-12 10:58:19 -07:00)
