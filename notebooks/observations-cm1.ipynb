# %%
# %run observations.ipynb

# %%
llc_file_id_agg_bw_file = '../vani/.digio/1670862281_cm1/llc-all-file_id-agg_bw.json'
llc_file_id_agg_bw_df = llc_to_df(json_file=llc_file_id_agg_bw_file, name='file > agg_bw', index_column='file', per_column='per_agg_bw')
llc_file_id_agg_bw_df
# Out:
#                  file > agg_bw                                              \
#                           file      % is_collective is_fpp is_mpi is_posix
# 0       ../cm1out_metadata.dat  0.00%         False   True  False     True
# 1  ../cm1out_diag_000342_s.dat  0.00%         False   True  False     True
# 2            ../cm1_config.txt  0.00%         False   True  False     True
# 3          ../cm1out_stats.ctl  0.00%         False   True  False     True
# 4              ../cm1out_s.ctl  0.00%         False   True  False     True
#
#                                                               all            \
#   is_read_only is_sequential is_write_only md_io_ratio     agg_bw   agg_dur
# 0        False         False          True      84.17%  0.000GB/s  0.000941
# 1        False          True          True      99.97%  0.000GB/s  0.325141
# 2        False         False          True      97.07%  0.001GB/s  0.002457
# 3        False         False          True      94.38%  0.001GB/s  2.220052
# 4        False         False          True      73.43%  0.001GB/s  0.042188
#
#                                        r     w
#   agg_size   ops files funcs ranks  xfer  xfer
# 0  0.000GB    48     1     6     1  <4KB   4KB
# 1  0.000GB     6     1     5     1  <4KB  64KB
# 2  0.000GB     8     1     7     1  <4KB   4KB
# 3  0.002GB  2528     1     7     1  <4KB  16KB
# 4  0.000GB    50     1     7     1  <4KB  16KB

# %%
llc_file_id_agg_dur_file = '../vani/.digio/1670862281_cm1/llc-all-file_id-agg_dur.json'
llc_file_id_agg_dur_df = llc_to_df(json_file=llc_file_id_agg_dur_file, name='file > agg_dur', index_column='file', per_column='per_agg_dur')
llc_file_id_agg_dur_df
# Out:
#                  file > agg_dur                                               \
#                            file       % is_collective is_fpp is_mpi is_posix
# 0        ../cm1out_000001_s.dat  37.80%         False   True  False     True
# 1           ../cm1out_stats.ctl  19.35%         False   True  False     True
# 2        ../cm1out_000005_s.dat   4.24%         False   True  False     True
# 3        ../cm1rst_000002_s.dat   4.03%         False   True  False     True
# 4        ../cm1out_000003_s.dat   3.28%         False   True  False     True
# 5        ../cm1out_000002_w.dat   3.04%         False   True  False     True
# 6        ../cm1out_000004_s.dat   2.93%         False   True  False     True
# 7   ../cm1out_diag_000342_s.dat   2.83%         False   True  False     True
# 8        ../cm1out_000002_s.dat   2.65%         False   True  False     True
# 9        ../cm1rst_000001_s.dat   1.92%         False   True  False     True
# 10       ../cm1out_000006_s.dat   1.54%         False   True  False     True
# 11         ../cm1out_diag_s.ctl   1.29%         False   True  False     True
# 12         ../cm1out_diag_w.ctl   1.11%         False   True  False     True
# 13       ../cm1out_000007_u.dat   0.93%         False   True  False     True
# 14       ../cm1out_000006_v.dat   0.77%         False   True  False     True
# 15       ../cm1out_000006_w.dat   0.57%         False   True  False     True
# 16       ../cm1out_000007_s.dat   0.53%         False   True  False     True
# 17       ../cm1out_000004_v.dat   0.42%         False   True  False     True
# 18              ../cm1out_s.ctl   0.37%         False   True  False     True
# 19       ../cm1out_000004_w.dat   0.33%         False   True  False     True
# 20       ../cm1out_000005_w.dat   0.30%         False   True  False     True
# 21  ../cm1out_diag_000093_s.dat   0.28%         False   True  False     True
# 22  ../cm1out_diag_000073_w.dat   0.26%         False   True  False     True
# 23  ../cm1out_diag_000190_s.dat   0.25%         False   True  False     True
# 24          ../cm1out_stats.dat   0.24%         False   True  False     True
# 25  ../cm1out_diag_000330_w.dat   0.23%         False   True  False     True
# 26  ../cm1out_diag_000217_w.dat   0.22%         False   True  False     True
# 27       ../cm1rst_000001_v.dat   0.21%         False   True  False     True
# 28  ../cm1out_diag_000022_w.dat   0.20%         False   True  False     True
# 29  ../cm1out_diag_000101_s.dat   0.19%         False   True  False     True
# 30                 ../proc.info   0.18%         False   True  False     True
# 31  ../cm1out_diag_000243_s.dat   0.17%         False   True  False     True
# 32       ../cm1out_000003_w.dat   0.10%         False   True  False     True
# 33       ../cm1out_000007_w.dat   0.10%         False   True  False     True
#
#                                                                all            \
#    is_read_only is_sequential is_write_only md_io_ratio     agg_bw   agg_dur
# 0         False          True          True      99.84%  0.010GB/s  4.336345
# 1         False         False          True      94.38%  0.001GB/s  2.220052
# 2         False          True          True      98.58%  0.085GB/s  0.486301
# 3         False          True          True      98.25%  0.094GB/s  0.462760
# 4         False          True          True      98.24%  0.110GB/s  0.376310
# 5         False          True          True      96.27%  0.226GB/s  0.348632
# 6         False          True          True      97.25%  0.123GB/s  0.336245
# 7         False          True          True      99.97%  0.000GB/s  0.325141
# 8         False          True          True      97.65%  0.136GB/s  0.304073
# 9         False          True          True      97.04%  0.198GB/s  0.220681
# 10        False          True          True      96.11%  0.235GB/s  0.176672
# 11        False         False          True      43.51%  0.032GB/s  0.147503
# 12        False         False          True      40.70%  0.036GB/s  0.127201
# 13        False          True          True      95.11%  0.073GB/s  0.107223
# 14        False          True          True      97.31%  0.090GB/s  0.087949
# 15        False          True          True      82.20%  1.208GB/s  0.065157
# 16        False          True          True      87.57%  0.685GB/s  0.060581
# 17        False          True          True      94.59%  0.163GB/s  0.048367
# 18        False         False          True      73.43%  0.001GB/s  0.042188
# 19        False          True          True      71.27%  2.054GB/s  0.038331
# 20        False          True          True      67.87%  2.294GB/s  0.034324
# 21        False          True          True      99.68%  0.001GB/s  0.031704
# 22        False          True          True      99.78%  0.001GB/s  0.030335
# 23        False          True          True      99.53%  0.002GB/s  0.029138
# 24        False         False          True      52.49%  0.003GB/s  0.027824
# 25        False          True          True      99.69%  0.002GB/s  0.026387
# 26        False          True          True      99.63%  0.002GB/s  0.024926
# 27        False          True          True      89.75%  0.323GB/s  0.024359
# 28        False          True          True      99.73%  0.002GB/s  0.023064
# 29        False          True          True      99.54%  0.002GB/s  0.021971
# 30        False         False          True      99.38%  0.005GB/s  0.020914
# 31        False          True          True      99.36%  0.002GB/s  0.019950
# 32        False          True          True       9.80%  6.979GB/s  0.011282
# 33        False          True          True       6.62%  7.098GB/s  0.011093
#
#                                         r      w
#    agg_size   ops files funcs ranks  xfer   xfer
# 0   0.042GB   242     1     5    32  <4KB   16MB
# 1   0.002GB  2528     1     7     1  <4KB   16KB
# 2   0.042GB   243     1     5    32  <4KB   16MB
# 3   0.044GB   232     1     5    32  <4KB   16MB
# 4   0.042GB   243     1     5    32  <4KB   16MB
# 5   0.079GB   229     1     5    32  <4KB   16MB
# 6   0.042GB   243     1     5    32  <4KB   16MB
# 7   0.000GB     6     1     5     1  <4KB   64KB
# 8   0.042GB   243     1     5    32  <4KB   16MB
# 9   0.044GB   206     1     5    32  <4KB   16MB
# 10  0.042GB   243     1     5    32  <4KB   16MB
# 11  0.005GB  2528     1     7     1  <4KB   16KB
# 12  0.005GB  2528     1     7     1  <4KB   16KB
# 13  0.008GB   199     1     5    32  <4KB   16MB
# 14  0.008GB   200     1     5    32  <4KB   16MB
# 15  0.079GB   205     1     5    32  <4KB   16MB
# 16  0.042GB   224     1     5    32  <4KB   16MB
# 17  0.008GB   195     1     5    32  <4KB   16MB
# 18  0.000GB    50     1     7     1  <4KB   16KB
# 19  0.079GB   200     1     5    32  <4KB   16MB
# 20  0.079GB   201     1     5    32  <4KB   16MB
# 21  0.000GB     6     1     5     1  <4KB   64KB
# 22  0.000GB     6     1     5     1  <4KB   64KB
# 23  0.000GB     6     1     5     1  <4KB   64KB
# 24  0.000GB  2526     1     6     1  <4KB    4KB
# 25  0.000GB     6     1     5     1  <4KB   64KB
# 26  0.000GB     6     1     5     1  <4KB   64KB
# 27  0.008GB   194     1     5    32  <4KB   16MB
# 28  0.000GB     6     1     5     1  <4KB   64KB
# 29  0.000GB     6     1     5     1  <4KB   64KB
# 30  0.000GB     8     1     7     1  <4KB  256KB
# 31  0.000GB     6     1     5     1  <4KB   64KB
# 32  0.079GB   199     1     5    32  <4KB   16MB
# 33  0.079GB   200     1     5    32  <4KB   16MB

# %%
llc_proc_id_agg_bw_file = '../vani/.digio/1670862281_cm1/llc-all-proc_id-agg_bw.json'
llc_proc_id_agg_bw_df = llc_to_df(json_file=llc_proc_id_agg_bw_file, name='proc > agg_bw', index_column='rank', per_column='per_agg_bw')
llc_proc_id_agg_bw_df
# Out:
#   proc > agg_bw                                                           \
#            rank      % is_collective is_fpp is_mpi is_posix is_read_only
# 0         [600]  0.00%         False   True  False     True         True
# 1         [400]  0.00%         False   True  False     True         True
# 2         [720]  0.00%         False   True  False     True         True
# 3         [360]  0.00%         False   True  False     True         True
# 4         [560]  0.00%         False   True  False     True         True
#
#                                                  all                          \
#   is_sequential is_write_only md_io_ratio     agg_bw   agg_dur agg_size  ops
# 0          True         False     100.00%  0.005GB/s  3.442541  0.016GB  162
# 1          True         False     100.00%  0.005GB/s  3.331736  0.016GB  159
# 2          True         False     100.00%  0.005GB/s  6.571376  0.031GB  320
# 3          True         False     100.00%  0.005GB/s  3.256698  0.016GB  162
# 4          True         False     100.00%  0.005GB/s  3.252609  0.016GB  164
#
#                         r     w
#   files funcs ranks  xfer  xfer
# 0    38     5     1  16MB  <4KB
# 1    38     5     1  16MB  <4KB
# 2    38     5     1  16MB  <4KB
# 3    38     5     1  16MB  <4KB
# 4    38     5     1  16MB  <4KB

# %%
llc_proc_id_agg_dur_file = '../vani/.digio/1670862281_cm1/llc-all-proc_id-agg_dur.json'
llc_proc_id_agg_dur_df = llc_to_df(json_file=llc_proc_id_agg_dur_file, name='proc > agg_dur', index_column='rank', per_column='per_agg_dur')
llc_proc_id_agg_dur_df
# Out:
#    proc > agg_dur                                                           \
#              rank      % is_collective is_fpp is_mpi is_posix is_read_only
# 0           [720]  4.57%         False   True  False     True         True
# 1          [1240]  4.50%         False   True  False     True         True
# 2          [1040]  4.27%         False   True  False     True         True
# 3          [1000]  4.26%         False   True  False     True         True
# 4           [840]  4.19%         False   True  False     True         True
# 5           [960]  4.13%         False   True  False     True         True
# 6          [1200]  4.13%         False   True  False     True         True
# 7          [1120]  4.10%         False   True  False     True         True
# 8           [880]  4.10%         False   True  False     True         True
# 9          [1080]  4.08%         False   True  False     True         True
# 10          [640]  4.01%         False   True  False     True         True
# 11         [1160]  3.87%         False   True  False     True         True
# 12          [760]  3.82%         False   True  False     True         True
# 13          [680]  3.75%         False   True  False     True         True
# 14          [800]  3.57%         False   True  False     True         True
# 15          [920]  3.56%         False   True  False     True         True
# 16            [0]  2.86%         False  False  False     True        False
# 17          [600]  2.39%         False   True  False     True         True
# 18          [400]  2.32%         False   True  False     True         True
# 19          [360]  2.26%         False   True  False     True         True
# 20          [560]  2.26%         False   True  False     True         True
# 21          [200]  2.25%         False   True  False     True         True
# 22           [80]  2.23%         False   True  False     True         True
# 23          [520]  2.22%         False   True  False     True         True
# 24          [320]  2.09%         False   True  False     True         True
# 25          [120]  2.07%         False   True  False     True         True
# 26           [40]  2.07%         False   True  False     True         True
# 27          [280]  2.06%         False   True  False     True         True
# 28          [440]  2.02%         False   True  False     True         True
# 29          [480]  1.98%         False   True  False     True         True
# 30          [240]  1.97%         False   True  False     True         True
# 31          [160]  1.94%         False   True  False     True         True
# 32         [1111]  0.00%         False   True  False     True         True
# 33         [1155]  0.00%         False   True  False     True         True
# 34         [1196]  0.00%         False   True  False     True         True
# 35          [794]  0.00%         False   True  False     True         True
#
#                                                    all                     \
#    is_sequential is_write_only md_io_ratio      agg_bw   agg_dur agg_size
# 0           True         False     100.00%   0.005GB/s  6.571376  0.031GB
# 1           True         False     100.00%   0.005GB/s  6.478860  0.031GB
# 2           True         False     100.00%   0.005GB/s  6.143349  0.031GB
# 3           True         False     100.00%   0.005GB/s  6.123565  0.031GB
# 4           True         False     100.00%   0.005GB/s  6.028044  0.031GB
# 5           True         False      99.96%   0.005GB/s  5.945679  0.031GB
# 6           True         False     100.00%   0.005GB/s  5.936991  0.031GB
# 7           True         False     100.00%   0.005GB/s  5.900002  0.031GB
# 8           True         False     100.00%   0.005GB/s  5.896172  0.031GB
# 9           True         False     100.00%   0.005GB/s  5.865581  0.031GB
# 10          True         False     100.00%   0.005GB/s  5.772859  0.031GB
# 11          True         False     100.00%   0.006GB/s  5.562261  0.031GB
# 12          True         False     100.00%   0.006GB/s  5.490247  0.031GB
# 13          True         False     100.00%   0.006GB/s  5.399219  0.031GB
# 14          True         False      99.98%   0.006GB/s  5.134389  0.031GB
# 15          True         False     100.00%   0.006GB/s  5.123828  0.031GB
# 16         False         False      85.89%   0.290GB/s  4.115100  1.193GB
# 17          True         False     100.00%   0.005GB/s  3.442541  0.016GB
# 18          True         False     100.00%   0.005GB/s  3.331736  0.016GB
# 19          True         False     100.00%   0.005GB/s  3.256698  0.016GB
# 20          True         False     100.00%   0.005GB/s  3.252609  0.016GB
# 21          True         False      99.97%   0.005GB/s  3.238349  0.016GB
# 22          True         False     100.00%   0.005GB/s  3.213426  0.016GB
# 23          True         False     100.00%   0.005GB/s  3.185860  0.016GB
# 24          True         False     100.00%   0.005GB/s  3.008699  0.016GB
# 25          True         False     100.00%   0.005GB/s  2.984170  0.016GB
# 26          True         False     100.00%   0.005GB/s  2.981486  0.016GB
# 27          True         False     100.00%   0.005GB/s  2.957242  0.016GB
# 28          True         False     100.00%   0.005GB/s  2.906523  0.016GB
# 29          True         False      99.98%   0.005GB/s  2.841209  0.016GB
# 30          True         False     100.00%   0.006GB/s  2.829356  0.016GB
# 31          True         False     100.00%   0.006GB/s  2.787134  0.016GB
# 32          True         False       6.79%   7.352GB/s  0.004251  0.031GB
# 33          True         False       8.74%   7.827GB/s  0.003993  0.031GB
# 34          True         False      10.45%  10.088GB/s  0.003098  0.031GB
# 35          True         False      10.62%  10.801GB/s  0.002893  0.031GB
#
#                                 r     w
#       ops files funcs ranks  xfer  xfer
# 0     320    38     5     1  16MB  <4KB
# 1     316    38     5     1  16MB  <4KB
# 2     318    38     5     1  16MB  <4KB
# 3     318    38     5     1  16MB  <4KB
# 4     316    38     5     1  16MB  <4KB
# 5     314    38     5     1  16MB  <4KB
# 6     320    38     5     1  16MB  <4KB
# 7     328    38     5     1  16MB  <4KB
# 8     316    38     5     1  16MB  <4KB
# 9     318    38     5     1  16MB  <4KB
# 10    316    38     5     1  16MB  <4KB
# 11    318    38     5     1  16MB  <4KB
# 12    322    38     5     1  16MB  <4KB
# 13    316    38     5     1  16MB  <4KB
# 14    320    38     5     1  16MB  <4KB
# 15    316    38     5     1  16MB  <4KB
# 16  15028   774     8     1  16MB   1MB
# 17    162    38     5     1  16MB  <4KB
# 18    159    38     5     1  16MB  <4KB
# 19    162    38     5     1  16MB  <4KB
# 20    164    38     5     1  16MB  <4KB
# 21    162    38     5     1  16MB  <4KB
# 22    161    38     5     1  16MB  <4KB
# 23    159    38     5     1  16MB  <4KB
# 24    158    38     5     1  16MB  <4KB
# 25    158    38     5     1  16MB  <4KB
# 26    161    38     5     1  16MB  <4KB
# 27    158    38     5     1  16MB  <4KB
# 28    157    38     5     1  16MB  <4KB
# 29    162    38     5     1  16MB  <4KB
# 30    160    38     5     1  16MB  <4KB
# 31    158    38     5     1  16MB  <4KB
# 32     12     2     5     1  16MB  <4KB
# 33     12     2     5     1  16MB  <4KB
# 34     12     2     5     1  16MB  <4KB
# 35     12     2     5     1  16MB  <4KB

# %%
llc_tmid_agg_bw_file = '../vani/.digio/1670862281_cm1/llc-all-tmid-agg_bw.json'
llc_tmid_agg_bw_df = llc_to_df(json_file=llc_tmid_agg_bw_file, name='time > agg_bw', index_column='time', per_column='per_agg_bw')
llc_tmid_agg_bw_df
# Out:
#    time > agg_bw                                                           \
#             time      % is_collective is_fpp is_mpi is_posix is_read_only
# 0  448.37-449.02  0.00%         False  False  False     True        False
# 1  633.06-633.72  0.00%         False  False  False     True        False
# 2  127.27-127.92  0.00%         False  False  False     True        False
# 3  666.35-667.00  0.00%         False  False  False     True        False
# 4  291.73-292.38  0.00%         False  False  False     True        False
#
#                                                  all                          \
#   is_sequential is_write_only md_io_ratio     agg_bw   agg_dur agg_size  ops
# 0         False          True      99.14%  0.000GB/s  0.405347  0.000GB  120
# 1         False          True      99.45%  0.000GB/s  0.327346  0.000GB   22
# 2         False          True      99.53%  0.000GB/s  0.298286  0.000GB  261
# 3         False          True      99.64%  0.000GB/s  0.053211  0.000GB  201
# 4         False          True      54.97%  0.001GB/s  0.004651  0.000GB   22
#
#                         r    w
#   files funcs ranks  xfer xfer
# 0     5     7    32  <4KB  4KB
# 1     4     7     1  <4KB  4KB
# 2     7     7    32  <4KB  4KB
# 3     5     7    32  <4KB  4KB
# 4     4     7     1  <4KB  4KB

# %%
llc_tmid_agg_dur_file = '../vani/.digio/1670862281_cm1/llc-all-tmid-agg_dur.json'
llc_tmid_agg_dur_df = llc_to_df(json_file=llc_tmid_agg_dur_file, name='time > agg_dur', index_column='time', per_column='per_agg_dur')
llc_tmid_agg_dur_df
# Out:
#    time > agg_dur                                                            \
#              time       % is_collective is_fpp is_mpi is_posix is_read_only
# 0       3.92-4.57  44.56%         False   True  False     True        False
# 1   449.02-449.67   5.08%         False  False  False     True        False
# 2   667.65-668.31   4.87%         False  False  False     True        False
# 3   448.37-449.02   4.17%         False  False  False     True        False
# 4   232.34-232.99   3.88%         False  False  False     True        False
# 5   343.29-343.94   3.67%         False  False  False     True        False
# 6   127.92-128.57   3.65%         False  False  False     True        False
# 7   633.06-633.72   3.37%         False  False  False     True        False
# 8   127.27-127.92   3.07%         False  False  False     True        False
# 9   560.62-561.27   2.79%         False  False  False     True        False
# 10  343.94-344.60   2.43%         False  False  False     True        False
# 11  667.00-667.65   1.34%         False  False  False     True        False
# 12      5.87-6.53   0.57%         False  False  False     True        False
# 13  666.35-667.00   0.55%         False  False  False     True        False
# 14  149.46-150.11   0.36%         False  False  False     True        False
# 15  184.05-184.70   0.34%         False  False  False     True        False
# 16  359.61-360.26   0.32%         False  False  False     True        False
# 17  612.18-612.83   0.29%         False  False  False     True        False
# 18  407.25-407.90   0.28%         False  False  False     True        False
# 19    59.39-60.04   0.26%         False  False  False     True        False
# 20  232.99-233.65   0.25%         False  False  False     True        False
# 21  198.40-199.06   0.24%         False  False  False     True        False
# 22  452.93-453.59   0.23%         False  False  False     True        False
# 23      2.61-3.26   0.22%         False  False  False     True        False
# 24  561.27-561.92   0.20%         False  False  False     True        False
# 25  449.67-450.32   0.17%         False  False  False     True        False
# 26  128.57-129.22   0.17%         False  False  False     True        False
# 27  344.60-345.25   0.13%         False  False  False     True        False
# 28      5.22-5.87   0.11%         False  False  False     True        False
# 29  555.40-556.05   0.11%         False  False  False     True        False
#
#                                                      all                      \
#    is_sequential is_write_only md_io_ratio        agg_bw   agg_dur  agg_size
# 0           True         False     100.00%     0.000GB/s  4.329440   0.000GB
# 1           True          True      97.24%     0.158GB/s  0.493820   0.078GB
# 2          False          True      96.40%     0.159GB/s  0.473415   0.075GB
# 3          False          True      99.14%     0.000GB/s  0.405347   0.000GB
# 4          False          True      98.07%     0.083GB/s  0.377375   0.031GB
# 5          False          True      95.45%     0.132GB/s  0.356407   0.047GB
# 6           True          True      94.68%     0.308GB/s  0.355114   0.109GB
# 7          False          True      99.45%     0.000GB/s  0.327346   0.000GB
# 8          False          True      99.53%     0.000GB/s  0.298286   0.000GB
# 9           True          True      94.77%     0.289GB/s  0.270690   0.078GB
# 10         False          True      90.97%     0.444GB/s  0.236340   0.105GB
# 11         False          True      78.96%     1.047GB/s  0.129842   0.136GB
# 12         False          True      69.17%     1.897GB/s  0.055275   0.105GB
# 13         False          True      99.64%     0.000GB/s  0.053211   0.000GB
# 14         False          True      91.34%     0.003GB/s  0.035283   0.000GB
# 15         False          True      98.73%     0.004GB/s  0.033469   0.000GB
# 16         False          True      98.65%     0.004GB/s  0.030777   0.000GB
# 17         False          True      98.58%     0.004GB/s  0.028371   0.000GB
# 18         False          True      98.38%     0.004GB/s  0.027276   0.000GB
# 19         False          True      97.99%     0.005GB/s  0.025102   0.000GB
# 20         False          True      18.09%     4.399GB/s  0.023841   0.105GB
# 21         False          True      98.40%     0.005GB/s  0.023607   0.000GB
# 22         False          True      97.96%     0.005GB/s  0.022143   0.000GB
# 23         False         False      96.70%  1218.800GB/s  0.021550  26.266GB
# 24         False          True      24.46%     2.937GB/s  0.019745   0.058GB
# 25         False          True      22.50%     3.421GB/s  0.016950   0.058GB
# 26         False          True      22.49%     1.639GB/s  0.016312   0.027GB
# 27          True          True       5.11%     4.702GB/s  0.012672   0.060GB
# 28         False          True      44.88%     2.849GB/s  0.010970   0.031GB
# 29         False          True      53.34%     0.012GB/s  0.010444   0.000GB
#
#                                 r      w
#       ops files funcs ranks  xfer   xfer
# 0      48     2     1    32  <4KB   <4KB
# 1     733     4     5    32  <4KB   16MB
# 2     841     9     7    32  <4KB   16MB
# 3     120     5     7    32  <4KB    4KB
# 4     501     8     7    32  <4KB   16MB
# 5     681     8     7    32  <4KB   16MB
# 6     619     4     5    32  <4KB   16MB
# 7      22     4     7     1  <4KB    4KB
# 8     261     7     7    32  <4KB    4KB
# 9     833     4     5    32  <4KB   16MB
# 10   1019    17     7    32  <4KB   16MB
# 11    681    10     7    32  <4KB   16MB
# 12    342    12     7    32  <4KB   16MB
# 13    201     5     7    32  <4KB    4KB
# 14     40     6     7     1  <4KB   64KB
# 15     40     6     7     1  <4KB   64KB
# 16     40     6     7     1  <4KB   64KB
# 17     40     6     7     1  <4KB   64KB
# 18     40     6     7     1  <4KB   64KB
# 19     40     6     7     1  <4KB   64KB
# 20    411    12     7    32  <4KB   16MB
# 21     40     6     7     1  <4KB   64KB
# 22     40     6     7     1  <4KB   64KB
# 23  10092     3     8  1132  16MB  256KB
# 24     64    12     7     1  <4KB   16MB
# 25     64    12     7     1  <4KB   16MB
# 26     62    12     7     1  <4KB    4MB
# 27     12     5     2     1  <4KB   16MB
# 28    479     8     7    32  <4KB   16MB
# 29     40     6     7     1  <4KB   64KB
