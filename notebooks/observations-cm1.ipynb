# %%
# %run observations.ipynb

# %%
llc_file_id_agg_bw_file = '../vani/.digio/1670646624_cm1/llc-all-file_id-agg_bw.json'
llc_file_id_agg_bw_df = llc_to_df(json_file=llc_file_id_agg_bw_file, name='file > agg_bw', index_column='file', per_column='per_agg_bw')
llc_file_id_agg_bw_df
# Out:
#                  file > agg_bw                                              \
#                           file      % is_collective is_fpp is_mpi is_posix
# 0       ../cm1out_metadata.dat  0.00%         False   True  False     True
# 1  ../cm1out_diag_000342_s.dat  0.00%         False   True  False     True
# 2            ../cm1_config.txt  0.00%         False   True  False     True
# 3          ../cm1out_stats.ctl  0.00%         False   True  False     True
# 4              ../cm1out_s.ctl  0.00%         False   True  False     True
#
#                                                               all            \
#   is_read_only is_sequential is_write_only md_io_ratio     agg_bw   agg_dur
# 0        False         False          True      84.17%  0.000GB/s  0.000941
# 1        False          True          True      99.97%  0.000GB/s  0.325141
# 2        False         False          True      97.07%  0.001GB/s  0.002457
# 3        False         False          True      94.38%  0.001GB/s  2.220052
# 4        False         False          True      73.43%  0.001GB/s  0.042188
#
#                                        r     w
#   agg_size   ops files funcs ranks  xfer  xfer
# 0  0.000GB    48     1     6     1  <4KB   4KB
# 1  0.000GB     6     1     5     1  <4KB  64KB
# 2  0.000GB     8     1     7     1  <4KB   4KB
# 3  0.002GB  2528     1     7     1  <4KB  16KB
# 4  0.000GB    50     1     7     1  <4KB  16KB

# %%
llc_file_id_agg_dur_file = '../vani/.digio/1670646624_cm1/llc-all-file_id-agg_dur.json'
llc_file_id_agg_dur_df = llc_to_df(json_file=llc_file_id_agg_dur_file, name='file > agg_dur', index_column='file', per_column='per_agg_dur')
llc_file_id_agg_dur_df
# Out:
#                  file > agg_dur                                               \
#                            file       % is_collective is_fpp is_mpi is_posix
# 0           ../cm1out_stats.ctl  28.06%         False   True  False     True
# 1        ../cm1out_000001_s.dat  27.79%         False   True  False     True
# 2   ../cm1out_diag_000342_s.dat   4.11%         False   True  False     True
# 3        ../cm1out_000005_s.dat   3.12%         False   True  False     True
# 4        ../cm1rst_000002_s.dat   2.99%         False   True  False     True
# 5        ../cm1out_000003_s.dat   2.51%         False   True  False     True
# 6        ../cm1out_000002_w.dat   2.29%         False   True  False     True
# 7        ../cm1out_000004_s.dat   2.20%         False   True  False     True
# 8        ../cm1rst_000001_s.dat   2.10%         False   True  False     True
# 9        ../cm1out_000002_s.dat   1.97%         False   True  False     True
# 10         ../cm1out_diag_s.ctl   1.86%         False   True  False     True
# 11         ../cm1out_diag_w.ctl   1.61%         False   True  False     True
# 12       ../cm1out_000006_s.dat   1.18%         False   True  False     True
# 13       ../cm1out_000007_u.dat   0.83%         False   True  False     True
# 14       ../cm1out_000006_w.dat   0.82%         False   True  False     True
# 15       ../cm1out_000006_v.dat   0.57%         False   True  False     True
# 16              ../cm1out_s.ctl   0.53%         False   True  False     True
# 17       ../cm1out_000007_s.dat   0.44%         False   True  False     True
# 18  ../cm1out_diag_000093_s.dat   0.40%         False   True  False     True
# 19  ../cm1out_diag_000073_w.dat   0.38%         False   True  False     True
# 20  ../cm1out_diag_000190_s.dat   0.37%         False   True  False     True
# 21          ../cm1out_stats.dat   0.35%         False   True  False     True
# 22       ../cm1out_000005_w.dat   0.35%         False   True  False     True
# 23  ../cm1out_diag_000330_w.dat   0.33%         False   True  False     True
# 24       ../cm1out_000004_v.dat   0.32%         False   True  False     True
# 25  ../cm1out_diag_000217_w.dat   0.32%         False   True  False     True
# 26       ../cm1out_000004_w.dat   0.31%         False   True  False     True
# 27       ../cm1rst_000001_v.dat   0.31%         False   True  False     True
# 28  ../cm1out_diag_000022_w.dat   0.29%         False   True  False     True
# 29  ../cm1out_diag_000101_s.dat   0.28%         False   True  False     True
# 30                 ../proc.info   0.26%         False   True  False     True
# 31  ../cm1out_diag_000243_s.dat   0.25%         False   True  False     True
# 32       ../cm1out_000003_w.dat   0.14%         False   True  False     True
# 33       ../cm1out_000007_w.dat   0.14%         False   True  False     True
# 34       ../cm1out_000005_u.dat   0.13%         False   True  False     True
# 35       ../cm1out_000001_w.dat   0.13%         False   True  False     True
#
#                                                                all            \
#    is_read_only is_sequential is_write_only md_io_ratio     agg_bw   agg_dur
# 0         False         False          True      94.38%  0.001GB/s  2.220052
# 1         False          True          True      99.69%  0.019GB/s  2.198721
# 2         False          True          True      99.97%  0.000GB/s  0.325141
# 3         False          True          True      97.21%  0.168GB/s  0.246595
# 4         False          True          True      96.58%  0.185GB/s  0.236232
# 5         False          True          True      96.66%  0.209GB/s  0.198618
# 6         False          True          True      92.81%  0.435GB/s  0.180820
# 7         False          True          True      94.70%  0.238GB/s  0.174131
# 8         False          True          True      96.08%  0.263GB/s  0.166459
# 9         False          True          True      95.42%  0.266GB/s  0.155769
# 10        False         False          True      43.51%  0.032GB/s  0.147503
# 11        False         False          True      40.70%  0.036GB/s  0.127201
# 12        False          True          True      92.67%  0.443GB/s  0.093738
# 13        False          True          True      92.03%  0.120GB/s  0.065799
# 14        False          True          True      82.20%  1.208GB/s  0.065157
# 15        False          True          True      94.79%  0.173GB/s  0.045404
# 16        False         False          True      73.43%  0.001GB/s  0.042188
# 17        False          True          True      78.33%  1.194GB/s  0.034759
# 18        False          True          True      99.68%  0.001GB/s  0.031704
# 19        False          True          True      99.78%  0.001GB/s  0.030335
# 20        False          True          True      99.53%  0.002GB/s  0.029139
# 21        False         False          True      52.49%  0.003GB/s  0.027824
# 22        False          True          True      60.31%  2.834GB/s  0.027786
# 23        False          True          True      99.69%  0.002GB/s  0.026387
# 24        False          True          True      89.74%  0.309GB/s  0.025491
# 25        False          True          True      99.63%  0.002GB/s  0.024926
# 26        False          True          True      55.37%  3.191GB/s  0.024671
# 27        False          True          True      89.75%  0.323GB/s  0.024359
# 28        False          True          True      99.73%  0.002GB/s  0.023064
# 29        False          True          True      99.54%  0.002GB/s  0.021971
# 30        False         False          True      99.38%  0.005GB/s  0.020914
# 31        False          True          True      99.36%  0.002GB/s  0.019950
# 32        False          True          True       9.80%  6.979GB/s  0.011282
# 33        False          True          True       3.42%  7.341GB/s  0.010726
# 34        False          True          True      65.72%  0.773GB/s  0.010192
# 35        False          True          True       3.30%  7.897GB/s  0.009970
#
#                                         r      w
#    agg_size   ops files funcs ranks  xfer   xfer
# 0   0.002GB  2528     1     7     1  <4KB   16KB
# 1   0.042GB   162     1     5    32  <4KB   16MB
# 2   0.000GB     6     1     5     1  <4KB   64KB
# 3   0.042GB   163     1     5    32  <4KB   16MB
# 4   0.044GB   156     1     5    32  <4KB   16MB
# 5   0.042GB   163     1     5    32  <4KB   16MB
# 6   0.079GB   154     1     5    32  <4KB   16MB
# 7   0.042GB   163     1     5    32  <4KB   16MB
# 8   0.044GB   141     1     5    32  <4KB   16MB
# 9   0.042GB   163     1     5    32  <4KB   16MB
# 10  0.005GB  2528     1     7     1  <4KB   16KB
# 11  0.005GB  2528     1     7     1  <4KB   16KB
# 12  0.042GB   163     1     5    32  <4KB   16MB
# 13  0.008GB   133     1     5    32  <4KB   16MB
# 14  0.079GB   139     1     5    32  <4KB   16MB
# 15  0.008GB   134     1     5    32  <4KB   16MB
# 16  0.000GB    50     1     7     1  <4KB   16KB
# 17  0.042GB   149     1     5    32  <4KB   16MB
# 18  0.000GB     6     1     5     1  <4KB   64KB
# 19  0.000GB     6     1     5     1  <4KB   64KB
# 20  0.000GB     6     1     5     1  <4KB   64KB
# 21  0.000GB  2526     1     6     1  <4KB    4KB
# 22  0.079GB   136     1     5    32  <4KB   16MB
# 23  0.000GB     6     1     5     1  <4KB   64KB
# 24  0.008GB   130     1     5    32  <4KB   16MB
# 25  0.000GB     6     1     5     1  <4KB   64KB
# 26  0.079GB   135     1     5    32  <4KB   16MB
# 27  0.008GB   130     1     5    32  <4KB   16MB
# 28  0.000GB     6     1     5     1  <4KB   64KB
# 29  0.000GB     6     1     5     1  <4KB   64KB
# 30  0.000GB     8     1     7     1  <4KB  256KB
# 31  0.000GB     6     1     5     1  <4KB   64KB
# 32  0.079GB   135     1     5    32  <4KB   16MB
# 33  0.079GB   135     1     5    32  <4KB   16MB
# 34  0.008GB   131     1     5    32  <4KB   16MB
# 35  0.079GB   135     1     5    32  <4KB   16MB

# %%
llc_proc_id_agg_bw_file = '../vani/.digio/1670646624_cm1/llc-all-proc_id-agg_bw.json'
llc_proc_id_agg_bw_df = llc_to_df(json_file=llc_proc_id_agg_bw_file, name='proc > agg_bw', index_column='rank', per_column='per_agg_bw')
llc_proc_id_agg_bw_df
# Out:
#   proc > agg_bw                                                           \
#            rank      % is_collective is_fpp is_mpi is_posix is_read_only
# 0         [600]  0.00%         False   True  False     True         True
# 1         [400]  0.00%         False   True  False     True         True
# 2         [720]  0.00%         False   True  False     True         True
# 3         [360]  0.00%         False   True  False     True         True
# 4         [560]  0.00%         False   True  False     True         True
#
#                                                  all                          \
#   is_sequential is_write_only md_io_ratio     agg_bw   agg_dur agg_size  ops
# 0          True         False     100.00%  0.005GB/s  3.442541  0.016GB  162
# 1          True         False     100.00%  0.005GB/s  3.331736  0.016GB  159
# 2          True         False     100.00%  0.005GB/s  3.285688  0.016GB  160
# 3          True         False     100.00%  0.005GB/s  3.256698  0.016GB  162
# 4          True         False     100.00%  0.005GB/s  3.252609  0.016GB  164
#
#                         r     w
#   files funcs ranks  xfer  xfer
# 0    38     5     1  16MB  <4KB
# 1    38     5     1  16MB  <4KB
# 2    38     5     1  16MB  <4KB
# 3    38     5     1  16MB  <4KB
# 4    38     5     1  16MB  <4KB

# %%
llc_proc_id_agg_dur_file = '../vani/.digio/1670646624_cm1/llc-all-proc_id-agg_dur.json'
llc_proc_id_agg_dur_df = llc_to_df(json_file=llc_proc_id_agg_dur_file, name='proc > agg_dur', index_column='rank', per_column='per_agg_dur')
llc_proc_id_agg_dur_df
# Out:
#    proc > agg_dur                                                           \
#              rank      % is_collective is_fpp is_mpi is_posix is_read_only
# 0             [0]  4.24%         False  False  False     True        False
# 1           [600]  3.55%         False   True  False     True         True
# 2           [400]  3.43%         False   True  False     True         True
# 3           [720]  3.38%         False   True  False     True         True
# 4           [360]  3.35%         False   True  False     True         True
# 5           [560]  3.35%         False   True  False     True         True
# 6          [1240]  3.34%         False   True  False     True         True
# 7           [200]  3.34%         False   True  False     True         True
# 8            [80]  3.31%         False   True  False     True         True
# 9           [520]  3.28%         False   True  False     True         True
# 10         [1040]  3.16%         False   True  False     True         True
# 11         [1000]  3.15%         False   True  False     True         True
# 12          [840]  3.10%         False   True  False     True         True
# 13          [320]  3.10%         False   True  False     True         True
# 14          [120]  3.07%         False   True  False     True         True
# 15           [40]  3.07%         False   True  False     True         True
# 16          [960]  3.06%         False   True  False     True         True
# 17         [1200]  3.06%         False   True  False     True         True
# 18          [280]  3.05%         False   True  False     True         True
# 19         [1120]  3.04%         False   True  False     True         True
# 20          [880]  3.04%         False   True  False     True         True
# 21         [1080]  3.02%         False   True  False     True         True
# 22          [440]  2.99%         False   True  False     True         True
# 23          [640]  2.97%         False   True  False     True         True
# 24          [480]  2.93%         False   True  False     True         True
# 25          [240]  2.91%         False   True  False     True         True
# 26          [160]  2.87%         False   True  False     True         True
# 27         [1160]  2.86%         False   True  False     True         True
# 28          [760]  2.83%         False   True  False     True         True
# 29          [680]  2.78%         False   True  False     True         True
# 30          [800]  2.64%         False   True  False     True         True
# 31          [920]  2.64%         False   True  False     True         True
# 32         [1111]  0.00%         False   True  False     True         True
# 33         [1155]  0.00%         False   True  False     True         True
# 34          [255]  0.00%         False   True  False     True         True
# 35          [634]  0.00%         False   True  False     True         True
#
#                                                   all                     \
#    is_sequential is_write_only md_io_ratio     agg_bw   agg_dur agg_size
# 0          False         False      85.89%  0.290GB/s  4.115100  1.193GB
# 1           True         False     100.00%  0.005GB/s  3.442541  0.016GB
# 2           True         False     100.00%  0.005GB/s  3.331736  0.016GB
# 3           True         False     100.00%  0.005GB/s  3.285688  0.016GB
# 4           True         False     100.00%  0.005GB/s  3.256698  0.016GB
# 5           True         False     100.00%  0.005GB/s  3.252609  0.016GB
# 6           True         False     100.00%  0.005GB/s  3.239430  0.016GB
# 7           True         False      99.97%  0.005GB/s  3.238349  0.016GB
# 8           True         False     100.00%  0.005GB/s  3.213426  0.016GB
# 9           True         False     100.00%  0.005GB/s  3.185860  0.016GB
# 10          True         False     100.00%  0.005GB/s  3.071674  0.016GB
# 11          True         False     100.00%  0.005GB/s  3.061782  0.016GB
# 12          True         False     100.00%  0.005GB/s  3.014022  0.016GB
# 13          True         False     100.00%  0.005GB/s  3.008698  0.016GB
# 14          True         False     100.00%  0.005GB/s  2.984170  0.016GB
# 15          True         False     100.00%  0.005GB/s  2.981485  0.016GB
# 16          True         False      99.96%  0.005GB/s  2.972840  0.016GB
# 17          True         False     100.00%  0.005GB/s  2.968495  0.016GB
# 18          True         False     100.00%  0.005GB/s  2.957242  0.016GB
# 19          True         False     100.00%  0.005GB/s  2.950001  0.016GB
# 20          True         False     100.00%  0.005GB/s  2.948086  0.016GB
# 21          True         False     100.00%  0.005GB/s  2.932791  0.016GB
# 22          True         False     100.00%  0.005GB/s  2.906523  0.016GB
# 23          True         False     100.00%  0.005GB/s  2.886429  0.016GB
# 24          True         False      99.98%  0.005GB/s  2.841209  0.016GB
# 25          True         False     100.00%  0.006GB/s  2.829355  0.016GB
# 26          True         False     100.00%  0.006GB/s  2.787134  0.016GB
# 27          True         False     100.00%  0.006GB/s  2.781130  0.016GB
# 28          True         False     100.00%  0.006GB/s  2.745123  0.016GB
# 29          True         False     100.00%  0.006GB/s  2.699609  0.016GB
# 30          True         False      99.98%  0.006GB/s  2.567195  0.016GB
# 31          True         False     100.00%  0.006GB/s  2.561914  0.016GB
# 32          True         False       6.79%  7.352GB/s  0.002125  0.016GB
# 33          True         False       8.74%  7.827GB/s  0.001996  0.016GB
# 34          True         False       6.81%  8.972GB/s  0.001742  0.016GB
# 35          True         False       8.24%  9.596GB/s  0.001628  0.016GB
#
#                                 r     w
#       ops files funcs ranks  xfer  xfer
# 0   15028   774     8     1  16MB   1MB
# 1     162    38     5     1  16MB  <4KB
# 2     159    38     5     1  16MB  <4KB
# 3     160    38     5     1  16MB  <4KB
# 4     162    38     5     1  16MB  <4KB
# 5     164    38     5     1  16MB  <4KB
# 6     158    38     5     1  16MB  <4KB
# 7     162    38     5     1  16MB  <4KB
# 8     161    38     5     1  16MB  <4KB
# 9     159    38     5     1  16MB  <4KB
# 10    159    38     5     1  16MB  <4KB
# 11    159    38     5     1  16MB  <4KB
# 12    158    38     5     1  16MB  <4KB
# 13    158    38     5     1  16MB  <4KB
# 14    158    38     5     1  16MB  <4KB
# 15    161    38     5     1  16MB  <4KB
# 16    157    38     5     1  16MB  <4KB
# 17    160    38     5     1  16MB  <4KB
# 18    158    38     5     1  16MB  <4KB
# 19    164    38     5     1  16MB  <4KB
# 20    158    38     5     1  16MB  <4KB
# 21    159    38     5     1  16MB  <4KB
# 22    157    38     5     1  16MB  <4KB
# 23    158    38     5     1  16MB  <4KB
# 24    162    38     5     1  16MB  <4KB
# 25    160    38     5     1  16MB  <4KB
# 26    158    38     5     1  16MB  <4KB
# 27    159    38     5     1  16MB  <4KB
# 28    161    38     5     1  16MB  <4KB
# 29    158    38     5     1  16MB  <4KB
# 30    160    38     5     1  16MB  <4KB
# 31    158    38     5     1  16MB  <4KB
# 32      6     2     5     1  16MB  <4KB
# 33      6     2     5     1  16MB  <4KB
# 34      6     2     5     1  16MB  <4KB
# 35      6     2     5     1  16MB  <4KB

# %%
llc_tmid_agg_bw_file = '../vani/.digio/1670646624_cm1/llc-all-tmid-agg_bw.json'
llc_tmid_agg_bw_df = llc_to_df(json_file=llc_tmid_agg_bw_file, name='time > agg_bw', index_column='time', per_column='per_agg_bw')
llc_tmid_agg_bw_df
# Out:
#    time > agg_bw                                                           \
#             time      % is_collective is_fpp is_mpi is_posix is_read_only
# 0  633.06-633.72  0.00%         False  False  False     True        False
# 1  448.37-449.02  0.00%         False  False  False     True        False
# 2  127.27-127.92  0.00%         False  False  False     True        False
# 3  666.35-667.00  0.00%         False  False  False     True        False
# 4  291.73-292.38  0.00%         False  False  False     True        False
#
#                                                  all                          \
#   is_sequential is_write_only md_io_ratio     agg_bw   agg_dur agg_size  ops
# 0         False          True      99.45%  0.000GB/s  0.327346  0.000GB   22
# 1         False          True      98.29%  0.000GB/s  0.204955  0.000GB   87
# 2         False          True      99.08%  0.000GB/s  0.149997  0.000GB  182
# 3         False          True      99.31%  0.000GB/s  0.027776  0.000GB  142
# 4         False          True      54.97%  0.001GB/s  0.004651  0.000GB   22
#
#                         r    w
#   files funcs ranks  xfer xfer
# 0     4     7     1  <4KB  4KB
# 1     5     7    32  <4KB  4KB
# 2     7     7    32  <4KB  4KB
# 3     5     7    32  <4KB  4KB
# 4     4     7     1  <4KB  4KB

# %%
llc_tmid_agg_dur_file = '../vani/.digio/1670646624_cm1/llc-all-tmid-agg_dur.json'
llc_tmid_agg_dur_df = llc_to_df(json_file=llc_tmid_agg_dur_file, name='time > agg_dur', index_column='time', per_column='per_agg_dur')
llc_tmid_agg_dur_df
# Out:
#    time > agg_dur                                                            \
#              time       % is_collective is_fpp is_mpi is_posix is_read_only
# 0       3.92-4.57  36.36%         False   True  False     True        False
# 1   633.06-633.72   5.43%         False  False  False     True        False
# 2   449.02-449.67   4.21%         False  False  False     True        False
# 3   667.65-668.31   4.07%         False  False  False     True        False
# 4   448.37-449.02   3.40%         False  False  False     True        False
# 5   232.34-232.99   3.36%         False  False  False     True        False
# 6   127.92-128.57   3.10%         False  False  False     True        False
# 7   343.29-343.94   3.09%         False  False  False     True        False
# 8   343.94-344.60   3.02%         False  False  False     True        False
# 9   560.62-561.27   2.88%         False  False  False     True        False
# 10  127.27-127.92   2.49%         False  False  False     True        False
# 11  667.00-667.65   1.46%         False  False  False     True        False
# 12      5.87-6.53   0.92%         False  False  False     True        False
# 13  149.46-150.11   0.59%         False  False  False     True        False
# 14  184.05-184.70   0.56%         False  False  False     True        False
# 15  359.61-360.26   0.51%         False  False  False     True        False
# 16  612.18-612.83   0.47%         False  False  False     True        False
# 17  666.35-667.00   0.46%         False  False  False     True        False
# 18  407.25-407.90   0.45%         False  False  False     True        False
# 19    59.39-60.04   0.42%         False  False  False     True        False
# 20  232.99-233.65   0.40%         False  False  False     True        False
# 21  198.40-199.06   0.39%         False  False  False     True        False
# 22  452.93-453.59   0.37%         False  False  False     True        False
# 23      2.61-3.26   0.36%         False  False  False     True        False
# 24  561.27-561.92   0.33%         False  False  False     True        False
# 25  449.67-450.32   0.28%         False  False  False     True        False
# 26  128.57-129.22   0.27%         False  False  False     True        False
# 27  344.60-345.25   0.21%         False  False  False     True        False
# 28      5.22-5.87   0.18%         False  False  False     True        False
# 29  555.40-556.05   0.17%         False  False  False     True        False
# 30  332.85-333.50   0.15%         False  False  False     True        False
# 31  503.84-504.49   0.14%         False  False  False     True        False
# 32  458.15-458.81   0.13%         False  False  False     True        False
# 33  345.90-346.55   0.13%         False  False  False     True        False
#
#                                                     all                      \
#    is_sequential is_write_only md_io_ratio       agg_bw   agg_dur  agg_size
# 0           True         False     100.00%    0.000GB/s  2.191843   0.000GB
# 1          False          True      99.45%    0.000GB/s  0.327346   0.000GB
# 2           True          True      94.63%    0.308GB/s  0.253719   0.078GB
# 3          False          True      93.07%    0.307GB/s  0.245619   0.075GB
# 4          False          True      98.29%    0.000GB/s  0.204955   0.000GB
# 5          False          True      96.40%    0.154GB/s  0.202468   0.031GB
# 6           True          True      89.89%    0.585GB/s  0.187008   0.109GB
# 7          False          True      91.29%    0.252GB/s  0.186315   0.047GB
# 8          False          True      88.28%    0.576GB/s  0.182146   0.105GB
# 9           True          True      91.85%    0.450GB/s  0.173633   0.078GB
# 10         False          True      99.08%    0.000GB/s  0.149997   0.000GB
# 11         False          True      69.02%    1.543GB/s  0.088169   0.136GB
# 12         False          True      69.17%    1.897GB/s  0.055275   0.105GB
# 13         False          True      91.34%    0.003GB/s  0.035283   0.000GB
# 14         False          True      98.73%    0.004GB/s  0.033469   0.000GB
# 15         False          True      98.65%    0.004GB/s  0.030777   0.000GB
# 16         False          True      98.58%    0.004GB/s  0.028371   0.000GB
# 17         False          True      99.31%    0.000GB/s  0.027776   0.000GB
# 18         False          True      98.38%    0.004GB/s  0.027276   0.000GB
# 19         False          True      97.99%    0.005GB/s  0.025102   0.000GB
# 20         False          True      18.09%    4.399GB/s  0.023841   0.105GB
# 21         False          True      98.40%    0.005GB/s  0.023607   0.000GB
# 22         False          True      97.96%    0.005GB/s  0.022143   0.000GB
# 23         False         False      96.70%  821.477GB/s  0.021550  17.703GB
# 24         False          True      24.46%    2.937GB/s  0.019745   0.058GB
# 25         False          True      22.50%    3.421GB/s  0.016950   0.058GB
# 26         False          True      22.49%    1.639GB/s  0.016312   0.027GB
# 27          True          True       5.11%    4.702GB/s  0.012672   0.060GB
# 28         False          True      44.88%    2.849GB/s  0.010970   0.031GB
# 29         False          True      53.34%    0.012GB/s  0.010444   0.000GB
# 30         False          True      45.83%    0.013GB/s  0.009334   0.000GB
# 31         False          True      28.55%    0.015GB/s  0.008164   0.000GB
# 32         False          True      30.73%    0.015GB/s  0.008054   0.000GB
# 33         False          True      73.89%    0.015GB/s  0.007851   0.000GB
#
#                                r      w
#      ops files funcs ranks  xfer   xfer
# 0     32     2     1    32  <4KB   <4KB
# 1     22     4     7     1  <4KB    4KB
# 2    491     4     5    32  <4KB   16MB
# 3    573     9     7    32  <4KB   16MB
# 4     87     5     7    32  <4KB    4KB
# 5    344     8     7    32  <4KB   16MB
# 6    415     4     5    32  <4KB   16MB
# 7    462     8     7    32  <4KB   16MB
# 8    706    17     7    32  <4KB   16MB
# 9    556     4     5    32  <4KB   16MB
# 10   182     7     7    32  <4KB    4KB
# 11   469    10     7    32  <4KB   16MB
# 12   251    12     7    32  <4KB   16MB
# 13    40     6     7     1  <4KB   64KB
# 14    40     6     7     1  <4KB   64KB
# 15    40     6     7     1  <4KB   64KB
# 16    40     6     7     1  <4KB   64KB
# 17   142     5     7    32  <4KB    4KB
# 18    40     6     7     1  <4KB   64KB
# 19    40     6     7     1  <4KB   64KB
# 20   296    12     7    32  <4KB   16MB
# 21    40     6     7     1  <4KB   64KB
# 22    40     6     7     1  <4KB   64KB
# 23  6804     3     8  1132  16MB  256KB
# 24    64    12     7     1  <4KB   16MB
# 25    64    12     7     1  <4KB   16MB
# 26    62    12     7     1  <4KB    4MB
# 27    12     5     2     1  <4KB   16MB
# 28   330     8     7    32  <4KB   16MB
# 29    40     6     7     1  <4KB   64KB
# 30    40     6     7     1  <4KB   64KB
# 31    40     6     7     1  <4KB   64KB
# 32    40     6     7     1  <4KB   64KB
# 33    40     6     7     1  <4KB   64KB
