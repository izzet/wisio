# %%
# %run observations.ipynb

# %%
llc_file_id_agg_bw_file = '../vani/.digio/1670226193_hacc/llc-all-file_id-agg_bw.json'
llc_file_id_agg_bw_df = llc_to_df(json_file=llc_file_id_agg_bw_file, name='file > agg_bw', index_column='file', per_column='per_agg_bw')
llc_file_id_agg_bw_df
# Out:
#                             file > agg_bw                                     \
#                                      file      % is_collective is_fpp is_mpi
# 0   ../test-Part00000173-of-00001280.data  0.34%         False   True  False
# 1   ../test-Part00000762-of-00001280.data  0.21%         False   True  False
# 2   ../test-Part00000934-of-00001280.data  0.20%         False   True  False
# 3   ../test-Part00000798-of-00001280.data  0.20%         False   True  False
# 4   ../test-Part00000789-of-00001280.data  0.18%         False   True  False
# ..                                    ...    ...           ...    ...    ...
# 67  ../test-Part00001277-of-00001280.data  0.14%         False   True  False
# 68  ../test-Part00000818-of-00001280.data  0.14%         False   True  False
# 69  ../test-Part00000765-of-00001280.data  0.14%         False   True  False
# 70  ../test-Part00001276-of-00001280.data  0.14%         False   True  False
# 71  ../test-Part00001070-of-00001280.data  0.14%         False   True  False
#
#                                                                         all  \
#    is_posix is_read_only is_sequential is_write_only md_io_ratio     agg_bw
# 0      True        False          True         False      19.47%  1.347GB/s
# 1      True        False          True         False       6.41%  0.838GB/s
# 2      True        False          True         False      81.69%  0.810GB/s
# 3      True        False          True         False       4.54%  0.801GB/s
# 4      True        False          True         False       4.77%  0.720GB/s
# ..      ...          ...           ...           ...         ...        ...
# 67     True        False          True         False       0.15%  0.573GB/s
# 68     True        False          True         False      44.78%  0.569GB/s
# 69     True        False          True         False       3.83%  0.568GB/s
# 70     True        False          True         False       0.78%  0.564GB/s
# 71     True        False          True         False      63.23%  0.563GB/s
#
#                                                 r     w
#      agg_dur agg_size ops files funcs ranks  xfer  xfer
# 0   0.916658  1.234GB  28     1     4     1  64MB  64MB
# 1   1.473826  1.234GB  28     1     4     1  64MB  64MB
# 2   1.524817  1.234GB  28     1     4     1  64MB  64MB
# 3   1.540852  1.234GB  28     1     4     1  64MB  64MB
# 4   1.714552  1.234GB  28     1     4     1  64MB  64MB
# ..       ...      ...  ..   ...   ...   ...   ...   ...
# 67  2.155393  1.234GB  28     1     4     1  64MB  64MB
# 68  2.169296  1.234GB  28     1     4     1  64MB  64MB
# 69  2.174353  1.234GB  28     1     4     1  64MB  64MB
# 70  2.187133  1.234GB  28     1     4     1  64MB  64MB
# 71  2.194024  1.234GB  28     1     4     1  64MB  64MB
#
# [72 rows x 19 columns]

# %%
llc_file_id_agg_dur_file = '../vani/.digio/1670226193_hacc/llc-all-file_id-agg_dur.json'
llc_file_id_agg_dur_df = llc_to_df(json_file=llc_file_id_agg_dur_file, name='file > agg_dur', index_column='file', per_column='per_agg_dur')
llc_file_id_agg_dur_df
# Out:
#                            file > agg_dur                                     \
#                                      file      % is_collective is_fpp is_mpi
# 0   ../test-Part00000085-of-00001280.data  0.17%         False   True  False
# 1   ../test-Part00000082-of-00001280.data  0.17%         False   True  False
# 2   ../test-Part00000093-of-00001280.data  0.17%         False   True  False
# 3   ../test-Part00000088-of-00001280.data  0.17%         False   True  False
# 4   ../test-Part00000119-of-00001280.data  0.17%         False   True  False
# ..                                    ...    ...           ...    ...    ...
# 74  ../test-Part00000178-of-00001280.data  0.14%         False   True  False
# 75  ../test-Part00000181-of-00001280.data  0.14%         False   True  False
# 76  ../test-Part00000177-of-00001280.data  0.14%         False   True  False
# 77  ../test-Part00000884-of-00001280.data  0.14%         False   True  False
# 78  ../test-Part00000825-of-00001280.data  0.14%         False   True  False
#
#                                                                         all  \
#    is_posix is_read_only is_sequential is_write_only md_io_ratio     agg_bw
# 0      True        False          True         False      81.50%  0.119GB/s
# 1      True        False          True         False      81.79%  0.120GB/s
# 2      True        False          True         False      81.84%  0.120GB/s
# 3      True        False          True         False      82.11%  0.120GB/s
# 4      True        False          True         False      82.27%  0.120GB/s
# ..      ...          ...           ...           ...         ...        ...
# 74     True        False          True         False      96.01%  0.146GB/s
# 75     True        False          True         False      96.24%  0.146GB/s
# 76     True        False          True         False      96.28%  0.146GB/s
# 77     True        False          True         False      87.65%  0.147GB/s
# 78     True        False          True         False      82.09%  0.147GB/s
#
#                                                  r     w
#       agg_dur agg_size ops files funcs ranks  xfer  xfer
# 0   10.367090  1.234GB  28     1     4     1  64MB  64MB
# 1   10.321397  1.234GB  28     1     4     1  64MB  64MB
# 2   10.316911  1.234GB  28     1     4     1  64MB  64MB
# 3   10.296043  1.234GB  28     1     4     1  64MB  64MB
# 4   10.259116  1.234GB  28     1     4     1  64MB  64MB
# ..        ...      ...  ..   ...   ...   ...   ...   ...
# 74   8.471968  1.234GB  28     1     4     1  64MB  64MB
# 75   8.458957  1.234GB  28     1     4     1  64MB  64MB
# 76   8.448879  1.234GB  28     1     4     1  64MB  64MB
# 77   8.415098  1.234GB  28     1     4     1  64MB  64MB
# 78   8.381701  1.234GB  28     1     4     1  64MB  64MB
#
# [79 rows x 19 columns]

# %%
llc_proc_id_agg_bw_file = '../vani/.digio/1670226193_hacc/llc-all-proc_id-agg_bw.json'
llc_proc_id_agg_bw_df = llc_to_df(json_file=llc_proc_id_agg_bw_file, name='proc > agg_bw', index_column='rank', per_column='per_agg_bw')
llc_proc_id_agg_bw_df
# Out:
#    proc > agg_bw                                                           \
#             rank      % is_collective is_fpp is_mpi is_posix is_read_only
# 0          [173]  0.34%         False   True  False     True        False
# 1          [762]  0.21%         False   True  False     True        False
# 2          [934]  0.20%         False   True  False     True        False
# 3          [798]  0.20%         False   True  False     True        False
# 4          [789]  0.18%         False   True  False     True        False
# ..           ...    ...           ...    ...    ...      ...          ...
# 67        [1277]  0.14%         False   True  False     True        False
# 68         [818]  0.14%         False   True  False     True        False
# 69         [765]  0.14%         False   True  False     True        False
# 70        [1276]  0.14%         False   True  False     True        False
# 71        [1070]  0.14%         False   True  False     True        False
#
#                                                   all                         \
#    is_sequential is_write_only md_io_ratio     agg_bw   agg_dur agg_size ops
# 0          False         False      19.50%  1.346GB/s  0.916972  1.234GB  57
# 1          False         False       6.45%  0.837GB/s  1.474557  1.234GB  57
# 2          False         False      81.70%  0.809GB/s  1.525642  1.234GB  57
# 3          False         False       4.58%  0.801GB/s  1.541433  1.234GB  57
# 4          False         False       4.79%  0.720GB/s  1.714938  1.234GB  57
# ..           ...           ...         ...        ...       ...      ...  ..
# 67         False         False       0.18%  0.573GB/s  2.156107  1.234GB  57
# 68         False         False      44.79%  0.569GB/s  2.169781  1.234GB  57
# 69         False         False       3.85%  0.568GB/s  2.174885  1.234GB  57
# 70         False         False       0.80%  0.564GB/s  2.187650  1.234GB  57
# 71         False         False      63.24%  0.563GB/s  2.194400  1.234GB  57
#
#                          r     w
#    files funcs ranks  xfer  xfer
# 0      3     8     1  64MB  64MB
# 1      3     8     1  64MB  64MB
# 2      3     8     1  64MB  64MB
# 3      3     8     1  64MB  64MB
# 4      3     8     1  64MB  64MB
# ..   ...   ...   ...   ...   ...
# 67     3     8     1  64MB  64MB
# 68     3     8     1  64MB  64MB
# 69     3     8     1  64MB  64MB
# 70     3     8     1  64MB  64MB
# 71     3     8     1  64MB  64MB
#
# [72 rows x 19 columns]

# %%
llc_proc_id_agg_dur_file = '../vani/.digio/1670226193_hacc/llc-all-proc_id-agg_dur.json'
llc_proc_id_agg_dur_df = llc_to_df(json_file=llc_proc_id_agg_dur_file, name='proc > agg_dur', index_column='rank', per_column='per_agg_dur')
llc_proc_id_agg_dur_df
# Out:
#    proc > agg_dur                                                           \
#              rank      % is_collective is_fpp is_mpi is_posix is_read_only
# 0            [85]  0.17%         False   True  False     True        False
# 1            [82]  0.17%         False   True  False     True        False
# 2            [93]  0.17%         False   True  False     True        False
# 3            [88]  0.17%         False   True  False     True        False
# 4           [119]  0.17%         False   True  False     True        False
# ..            ...    ...           ...    ...    ...      ...          ...
# 74          [178]  0.14%         False   True  False     True        False
# 75          [181]  0.14%         False   True  False     True        False
# 76          [177]  0.14%         False   True  False     True        False
# 77          [884]  0.14%         False   True  False     True        False
# 78          [825]  0.14%         False   True  False     True        False
#
#                                                   all                          \
#    is_sequential is_write_only md_io_ratio     agg_bw    agg_dur agg_size ops
# 0          False         False      81.50%  0.119GB/s  10.367437  1.234GB  57
# 1          False         False      81.80%  0.120GB/s  10.321701  1.234GB  57
# 2          False         False      81.85%  0.120GB/s  10.317753  1.234GB  57
# 3          False         False      82.11%  0.120GB/s  10.296583  1.234GB  57
# 4          False         False      82.27%  0.120GB/s  10.259436  1.234GB  57
# ..           ...           ...         ...        ...        ...      ...  ..
# 74         False         False      96.01%  0.146GB/s   8.472392  1.234GB  57
# 75         False         False      96.24%  0.146GB/s   8.459524  1.234GB  57
# 76         False         False      96.28%  0.146GB/s   8.449605  1.234GB  57
# 77         False         False      87.65%  0.147GB/s   8.415693  1.234GB  57
# 78         False         False      82.09%  0.147GB/s   8.382321  1.234GB  57
#
#                          r     w
#    files funcs ranks  xfer  xfer
# 0      3     8     1  64MB  64MB
# 1      3     8     1  64MB  64MB
# 2      3     8     1  64MB  64MB
# 3      3     8     1  64MB  64MB
# 4      3     8     1  64MB  64MB
# ..   ...   ...   ...   ...   ...
# 74     3     8     1  64MB  64MB
# 75     3     8     1  64MB  64MB
# 76     3     8     1  64MB  64MB
# 77     3     8     1  64MB  64MB
# 78     3     8     1  64MB  64MB
#
# [79 rows x 19 columns]

# %%
llc_tmid_agg_bw_file = '../vani/.digio/1670226193_hacc/llc-all-tmid-agg_bw.json'
llc_tmid_agg_bw_df = llc_to_df(json_file=llc_tmid_agg_bw_file, name='time > agg_bw', index_column='time', per_column='per_agg_bw')
llc_tmid_agg_bw_df
# Out:
#     time > agg_bw                                                           \
#              time      % is_collective is_fpp is_mpi is_posix is_read_only
# 0     20.54-20.57  1.00%         False   True  False     True        False
# 1     30.61-30.64  0.98%         False   True  False     True         True
# 2     26.99-27.02  0.92%         False   True  False     True         True
# 3     27.05-27.09  0.81%         False   True  False     True         True
# 4     30.58-30.61  0.80%         False   True  False     True         True
# ..            ...    ...           ...    ...    ...      ...          ...
# 240   24.59-24.62  0.14%         False   True  False     True         True
# 241   21.69-21.72  0.14%         False   True  False     True        False
# 242   28.07-28.11  0.14%         False   True  False     True         True
# 243   13.72-13.76  0.14%         False   True  False     True        False
# 244   15.86-15.90  0.14%         False   True  False     True        False
#
#                                                     all                     \
#     is_sequential is_write_only md_io_ratio      agg_bw   agg_dur agg_size
# 0           False         False       0.26%  35.735GB/s  0.209223  7.477GB
# 1           False         False       0.03%  35.018GB/s  0.051760  1.812GB
# 2           False         False       2.67%  33.001GB/s  0.013494  0.445GB
# 3           False         False       2.92%  28.864GB/s  0.012180  0.352GB
# 4           False         False       0.06%  28.663GB/s  0.040339  1.156GB
# ..            ...           ...         ...         ...       ...      ...
# 240         False         False       0.01%   5.106GB/s  0.281557  1.438GB
# 241         False         False       0.10%   5.093GB/s  0.943444  4.805GB
# 242         False         False       0.03%   5.046GB/s  0.204388  1.031GB
# 243         False          True       1.10%   5.041GB/s  0.370391  1.867GB
# 244         False         False       0.12%   5.032GB/s  0.664492  3.344GB
#
#                                 r      w
#      ops files funcs ranks   xfer   xfer
# 0    260    99     5   135  >64MB   64MB
# 1     41    17     2    17  >64MB   <4KB
# 2     66    20     4    20   64MB   <4KB
# 3     63    20     4    20   64MB   <4KB
# 4     38    13     2    15  >64MB   <4KB
# ..   ...   ...   ...   ...    ...    ...
# 240   58    29     3    40  >64MB   <4KB
# 241  164    74     5    80  >64MB   64MB
# 242   28    15     3    17  >64MB   <4KB
# 243   57    20     3    25   <4KB  >64MB
# 244  110    41     5    49  >64MB  >64MB
#
# [245 rows x 19 columns]

# %%
llc_tmid_agg_dur_file = '../vani/.digio/1670226193_hacc/llc-all-tmid-agg_dur.json'
llc_tmid_agg_dur_df = llc_to_df(json_file=llc_tmid_agg_dur_file, name='time > agg_dur', index_column='time', per_column='per_agg_dur')
llc_tmid_agg_dur_df
# Out:
#     time > agg_dur                                                           \
#               time      % is_collective is_fpp is_mpi is_posix is_read_only
# 0        9.18-9.22  0.82%         False   True  False     True        False
# 1        9.28-9.31  0.79%         False   True  False     True        False
# 2        9.31-9.35  0.78%         False   True  False     True        False
# 3        9.25-9.28  0.77%         False   True  False     True        False
# 4        9.22-9.25  0.76%         False   True  False     True        False
# ..             ...    ...           ...    ...    ...      ...          ...
# 157    13.00-13.03  0.15%         False   True  False     True        False
# 158    16.09-16.13  0.14%         False   True  False     True        False
# 159    13.20-13.23  0.14%         False   True  False     True        False
# 160    16.00-16.03  0.14%         False   True  False     True        False
# 161    20.90-20.93  0.13%         False   True  False     True        False
#
#                                                    all                     \
#     is_sequential is_write_only md_io_ratio     agg_bw   agg_dur agg_size
# 0           False          True      96.39%  0.034GB/s  9.125176  0.312GB
# 1           False          True      96.30%  0.057GB/s  8.763607  0.500GB
# 2           False          True      96.89%  0.143GB/s  8.711715  1.250GB
# 3           False          True      96.24%  0.029GB/s  8.552030  0.250GB
# 4           False          True      96.09%  0.022GB/s  8.462316  0.188GB
# ..            ...           ...         ...        ...       ...      ...
# 157         False         False      26.65%  1.804GB/s  1.697994  3.062GB
# 158         False         False       0.09%  0.973GB/s  1.573414  1.531GB
# 159         False         False       0.18%  1.812GB/s  1.564823  2.836GB
# 160         False         False       0.01%  1.531GB/s  1.561543  2.391GB
# 161         False         False       0.10%  4.806GB/s  1.494019  7.180GB
#
#                                 r      w
#      ops files funcs ranks   xfer   xfer
# 0     33    13     4    27   <4KB   64MB
# 1     33    13     4    31   <4KB   64MB
# 2     48    22     3    37   <4KB   64MB
# 3     17     8     4    17   <4KB   64MB
# 4     13     5     3    13   <4KB   64MB
# ..   ...   ...   ...   ...    ...    ...
# 157  117    54     5    69  >64MB   64MB
# 158   59    26     4    28   64MB   64MB
# 159  103    41     5    46   64MB   64MB
# 160   77    28     5    34  >64MB  >64MB
# 161  252   109     5   134  >64MB   64MB
#
# [162 rows x 19 columns]
