# %%
# %run observations.ipynb

# %%
llc_file_id_agg_bw_file = '../vani/.digio/1671687062_hacc/llc-all-file_id-agg_bw.json'
llc_file_id_agg_bw_df = llc_to_df(json_file=llc_file_id_agg_bw_file, name='file > agg_bw', index_column='file', per_column='per_agg_bw')
llc_file_id_agg_bw_df
# Out:
#                            file > agg_bw                                    \
#                                     file      % time_start time_end is_fpp
# 0  ../test-Part00000085-of-00001280.data  0.03%       5.09    26.75   True
# 1  ../test-Part00000082-of-00001280.data  0.03%       4.72    26.31   True
# 2  ../test-Part00000093-of-00001280.data  0.03%       4.82    26.44   True
# 3  ../test-Part00000088-of-00001280.data  0.03%       4.75    26.19   True
# 4  ../test-Part00000119-of-00001280.data  0.03%       4.81    26.12   True
#
#                                                                         \
#   is_mpi is_posix is_read_only is_sequential is_write_only md_io_ratio
# 0  False     True        False         False         False      81.50%
# 1  False     True        False         False         False      81.80%
# 2  False     True        False         False         False      81.84%
# 3  False     True        False         False         False      82.11%
# 4  False     True        False         False         False      82.27%
#
#          all                                               r     w
#       agg_bw    agg_dur agg_size ops files funcs ranks  xfer  xfer
# 0  0.119GB/s  10.367186  1.234GB  48     1     5     1  64MB  64MB
# 1  0.120GB/s  10.321504  1.234GB  48     1     5     1  64MB  64MB
# 2  0.120GB/s  10.317015  1.234GB  48     1     5     1  64MB  64MB
# 3  0.120GB/s  10.296164  1.234GB  48     1     5     1  64MB  64MB
# 4  0.120GB/s  10.259216  1.234GB  48     1     5     1  64MB  64MB

# %%
llc_file_id_agg_dur_file = '../vani/.digio/1671687062_hacc/llc-all-file_id-agg_dur.json'
llc_file_id_agg_dur_df = llc_to_df(json_file=llc_file_id_agg_dur_file, name='file > agg_dur', index_column='file', per_column='per_agg_dur')
llc_file_id_agg_dur_df
# Out:
#                            file > agg_dur                                    \
#                                      file      % time_start time_end is_fpp
# 0   ../test-Part00000085-of-00001280.data  0.17%       5.09    26.75   True
# 1   ../test-Part00000082-of-00001280.data  0.17%       4.72    26.31   True
# 2   ../test-Part00000093-of-00001280.data  0.17%       4.82    26.44   True
# 3   ../test-Part00000088-of-00001280.data  0.17%       4.75    26.19   True
# 4   ../test-Part00000119-of-00001280.data  0.17%       4.81    26.12   True
# ..                                    ...    ...        ...      ...    ...
# 74  ../test-Part00000178-of-00001280.data  0.14%       4.83    23.50   True
# 75  ../test-Part00000181-of-00001280.data  0.14%       4.82    23.41   True
# 76  ../test-Part00000177-of-00001280.data  0.14%       4.80    23.46   True
# 77  ../test-Part00000884-of-00001280.data  0.14%       4.85    24.89   True
# 78  ../test-Part00000825-of-00001280.data  0.14%       4.78    25.02   True
#
#                                                                          \
#    is_mpi is_posix is_read_only is_sequential is_write_only md_io_ratio
# 0   False     True        False         False         False      81.50%
# 1   False     True        False         False         False      81.80%
# 2   False     True        False         False         False      81.84%
# 3   False     True        False         False         False      82.11%
# 4   False     True        False         False         False      82.27%
# ..    ...      ...          ...           ...           ...         ...
# 74  False     True        False         False         False      96.01%
# 75  False     True        False         False         False      96.24%
# 76  False     True        False         False         False      96.28%
# 77  False     True        False         False         False      87.65%
# 78  False     True        False         False         False      82.09%
#
#           all                                               r     w
#        agg_bw    agg_dur agg_size ops files funcs ranks  xfer  xfer
# 0   0.119GB/s  10.367186  1.234GB  48     1     5     1  64MB  64MB
# 1   0.120GB/s  10.321504  1.234GB  48     1     5     1  64MB  64MB
# 2   0.120GB/s  10.317015  1.234GB  48     1     5     1  64MB  64MB
# 3   0.120GB/s  10.296164  1.234GB  48     1     5     1  64MB  64MB
# 4   0.120GB/s  10.259216  1.234GB  48     1     5     1  64MB  64MB
# ..        ...        ...      ...  ..   ...   ...   ...   ...   ...
# 74  0.146GB/s   8.472072  1.234GB  48     1     5     1  64MB  64MB
# 75  0.146GB/s   8.459087  1.234GB  48     1     5     1  64MB  64MB
# 76  0.146GB/s   8.448969  1.234GB  48     1     5     1  64MB  64MB
# 77  0.147GB/s   8.415188  1.234GB  48     1     5     1  64MB  64MB
# 78  0.147GB/s   8.381805  1.234GB  48     1     5     1  64MB  64MB
#
# [79 rows x 20 columns]

# %%
llc_proc_id_agg_bw_file = '../vani/.digio/1671687062_hacc/llc-all-proc_id-agg_bw.json'
llc_proc_id_agg_bw_df = llc_to_df(json_file=llc_proc_id_agg_bw_file, name='proc > agg_bw', index_column='rank', per_column='per_agg_bw')
llc_proc_id_agg_bw_df
# Out:
#   proc > agg_bw                                                    \
#            rank      % time_start time_end is_fpp is_mpi is_posix
# 0          [85]  0.03%       3.83    28.01   True  False     True
# 1          [82]  0.03%       3.95    27.68   True  False     True
# 2          [93]  0.03%       3.90    27.74   True  False     True
# 3          [88]  0.03%       3.94    27.72   True  False     True
# 4         [119]  0.03%       3.93    27.63   True  False     True
#
#                                                               all             \
#   is_read_only is_sequential is_write_only md_io_ratio     agg_bw    agg_dur
# 0        False         False         False      81.50%  0.119GB/s  10.367437
# 1        False         False         False      81.80%  0.120GB/s  10.321701
# 2        False         False         False      81.85%  0.120GB/s  10.317753
# 3        False         False         False      82.11%  0.120GB/s  10.296583
# 4        False         False         False      82.27%  0.120GB/s  10.259436
#
#                                      r     w
#   agg_size ops files funcs ranks  xfer  xfer
# 0  1.234GB  57     3     8     1  64MB  64MB
# 1  1.234GB  57     3     8     1  64MB  64MB
# 2  1.234GB  57     3     8     1  64MB  64MB
# 3  1.234GB  57     3     8     1  64MB  64MB
# 4  1.234GB  57     3     8     1  64MB  64MB

# %%
llc_proc_id_agg_dur_file = '../vani/.digio/1671687062_hacc/llc-all-proc_id-agg_dur.json'
llc_proc_id_agg_dur_df = llc_to_df(json_file=llc_proc_id_agg_dur_file, name='proc > agg_dur', index_column='rank', per_column='per_agg_dur')
llc_proc_id_agg_dur_df
# Out:
#    proc > agg_dur                                                    \
#              rank      % time_start time_end is_fpp is_mpi is_posix
# 0            [85]  0.17%       3.83    28.01   True  False     True
# 1            [82]  0.17%       3.95    27.68   True  False     True
# 2            [93]  0.17%       3.90    27.74   True  False     True
# 3            [88]  0.17%       3.94    27.72   True  False     True
# 4           [119]  0.17%       3.93    27.63   True  False     True
# ..            ...    ...        ...      ...    ...    ...      ...
# 74          [178]  0.14%       3.91    26.77   True  False     True
# 75          [181]  0.14%       3.95    26.76   True  False     True
# 76          [177]  0.14%       3.92    26.75   True  False     True
# 77          [884]  0.14%       3.91    27.08   True  False     True
# 78          [825]  0.14%       3.94    26.96   True  False     True
#
#                                                                all             \
#    is_read_only is_sequential is_write_only md_io_ratio     agg_bw    agg_dur
# 0         False         False         False      81.50%  0.119GB/s  10.367437
# 1         False         False         False      81.80%  0.120GB/s  10.321701
# 2         False         False         False      81.85%  0.120GB/s  10.317753
# 3         False         False         False      82.11%  0.120GB/s  10.296583
# 4         False         False         False      82.27%  0.120GB/s  10.259436
# ..          ...           ...           ...         ...        ...        ...
# 74        False         False         False      96.01%  0.146GB/s   8.472392
# 75        False         False         False      96.24%  0.146GB/s   8.459524
# 76        False         False         False      96.28%  0.146GB/s   8.449605
# 77        False         False         False      87.65%  0.147GB/s   8.415693
# 78        False         False         False      82.09%  0.147GB/s   8.382321
#
#                                       r     w
#    agg_size ops files funcs ranks  xfer  xfer
# 0   1.234GB  57     3     8     1  64MB  64MB
# 1   1.234GB  57     3     8     1  64MB  64MB
# 2   1.234GB  57     3     8     1  64MB  64MB
# 3   1.234GB  57     3     8     1  64MB  64MB
# 4   1.234GB  57     3     8     1  64MB  64MB
# ..      ...  ..   ...   ...   ...   ...   ...
# 74  1.234GB  57     3     8     1  64MB  64MB
# 75  1.234GB  57     3     8     1  64MB  64MB
# 76  1.234GB  57     3     8     1  64MB  64MB
# 77  1.234GB  57     3     8     1  64MB  64MB
# 78  1.234GB  57     3     8     1  64MB  64MB
#
# [79 rows x 20 columns]

# %%
llc_tmid_agg_bw_file = '../vani/.digio/1671687062_hacc/llc-all-tmid-agg_bw.json'
llc_tmid_agg_bw_df = llc_to_df(json_file=llc_tmid_agg_bw_file, name='time > agg_bw', index_column='time', per_column='per_agg_bw')
llc_tmid_agg_bw_df
# Out:
#   time > agg_bw                                                           \
#            time      % is_fpp is_mpi is_posix is_read_only is_sequential
# 0     8.56-8.59  0.00%   True  False     True         True          True
# 1     8.59-8.62  0.00%   True  False     True         True          True
# 2     8.26-8.29  0.00%   True  False     True         True          True
# 3     7.37-7.41  0.00%   True  False     True        False          True
# 4     7.44-7.47  0.00%   True  False     True        False         False
#
#                                    all                                     \
#   is_write_only md_io_ratio     agg_bw   agg_dur agg_size ops files funcs
# 0         False      99.85%  0.003GB/s  7.795041  0.023GB  34    23     4
# 1         False      99.88%  0.003GB/s  7.475098  0.023GB  28    19     3
# 2         False      99.85%  0.003GB/s  6.960895  0.023GB  26    22     4
# 3          True      97.66%  0.004GB/s  5.414457  0.023GB   4     4     2
# 4          True      99.95%  0.004GB/s  5.396223  0.023GB  44    18     7
#
#             r     w
#   ranks  xfer  xfer
# 0    23  64MB  <4KB
# 1    19  64MB  <4KB
# 2    22  64MB  <4KB
# 3     4  <4KB  64MB
# 4    18  <4KB  64MB

# %%
llc_tmid_agg_dur_file = '../vani/.digio/1671687062_hacc/llc-all-tmid-agg_dur.json'
llc_tmid_agg_dur_df = llc_to_df(json_file=llc_tmid_agg_dur_file, name='time > agg_dur', index_column='time', per_column='per_agg_dur')
llc_tmid_agg_dur_df
# Out:
#     time > agg_dur                                                           \
#               time      % is_fpp is_mpi is_posix is_read_only is_sequential
# 0        9.18-9.22  0.82%   True  False     True        False         False
# 1        9.28-9.31  0.79%   True  False     True        False         False
# 2        9.31-9.35  0.78%   True  False     True        False         False
# 3        9.25-9.28  0.77%   True  False     True        False         False
# 4        9.22-9.25  0.76%   True  False     True        False         False
# ..             ...    ...    ...    ...      ...          ...           ...
# 157    13.00-13.03  0.15%   True  False     True        False         False
# 158    16.09-16.13  0.14%   True  False     True        False         False
# 159    13.20-13.23  0.14%   True  False     True        False         False
# 160    16.00-16.03  0.14%   True  False     True        False         False
# 161    20.90-20.93  0.13%   True  False     True        False         False
#
#                                      all                                      \
#     is_write_only md_io_ratio     agg_bw   agg_dur agg_size  ops files funcs
# 0            True      96.39%  0.034GB/s  9.125176  0.312GB   33    27     4
# 1            True      96.30%  0.057GB/s  8.763607  0.500GB   33    31     4
# 2            True      96.89%  0.143GB/s  8.711715  1.250GB   48    37     3
# 3            True      96.24%  0.029GB/s  8.552030  0.250GB   17    17     4
# 4            True      96.09%  0.022GB/s  8.462316  0.188GB   13    13     3
# ..            ...         ...        ...       ...      ...  ...   ...   ...
# 157         False      26.65%  1.804GB/s  1.697994  3.062GB  117    69     5
# 158         False       0.09%  0.973GB/s  1.573414  1.531GB   59    28     4
# 159         False       0.18%  1.812GB/s  1.564823  2.836GB  103    46     5
# 160         False       0.01%  1.531GB/s  1.561543  2.391GB   77    34     5
# 161         False       0.10%  4.806GB/s  1.494019  7.180GB  252   134     5
#
#                r      w
#     ranks   xfer   xfer
# 0      27   <4KB   64MB
# 1      31   <4KB   64MB
# 2      37   <4KB   64MB
# 3      17   <4KB   64MB
# 4      13   <4KB   64MB
# ..    ...    ...    ...
# 157    69  >64MB   64MB
# 158    28   64MB   64MB
# 159    46   64MB   64MB
# 160    34  >64MB  >64MB
# 161   134  >64MB   64MB
#
# [162 rows x 18 columns]
