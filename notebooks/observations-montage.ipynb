# %%
# %run observations.ipynb

# %%
llc_file_id_agg_bw_file = '../vani/.digio/1670872087_montage/llc-all-file_id-agg_bw.json'
llc_file_id_agg_bw_df = llc_to_df(json_file=llc_file_id_agg_bw_file, name='file > agg_bw', index_column='file', per_column='per_agg_bw')
llc_file_id_agg_bw_df
# Out:
#     file > agg_bw                                                           \
#              file      % is_collective is_fpp is_mpi is_posix is_read_only
# 0  ../Kimages.tbl  0.00%         False   True  False     True        False
# 1   ../images.tbl  0.00%         False   True  False     True        False
# 2  ../Kimages.tbl  0.00%         False   True  False     True        False
# 3  ../Kimages.tbl  0.00%         False   True  False     True        False
# 4  ../Kimages.tbl  0.00%         False   True  False     True        False
#
#                                                  all                          \
#   is_sequential is_write_only md_io_ratio     agg_bw   agg_dur agg_size  ops
# 0         False          True      99.88%  0.000GB/s  0.009957  0.000GB  507
# 1         False          True      99.70%  0.000GB/s  0.003082  0.000GB  511
# 2         False          True      99.36%  0.000GB/s  0.002022  0.000GB  507
# 3         False          True      99.36%  0.000GB/s  0.001850  0.000GB  507
# 4         False          True      99.39%  0.000GB/s  0.001833  0.000GB  507
#
#                         r    w
#   files funcs ranks  xfer xfer
# 0     1     6     1  <4KB  4KB
# 1     1     6     5  <4KB  4KB
# 2     1     6     1  <4KB  4KB
# 3     1     6     1  <4KB  4KB
# 4     1     6     1  <4KB  4KB

# %%
llc_file_id_agg_dur_file = '../vani/.digio/1670872087_montage/llc-all-file_id-agg_dur.json'
llc_file_id_agg_dur_df = llc_to_df(json_file=llc_file_id_agg_dur_file, name='file > agg_dur', index_column='file', per_column='per_agg_dur')
llc_file_id_agg_dur_df
# Out:
#                                     file > agg_dur                        \
#                                               file       % is_collective
# 0                                  ../ngc3372.fits  12.40%         False
# 1                                  ../ngc3372.fits   6.29%         False
# 2                                  ../ngc3372.fits   3.66%         False
# 3                                  ../ngc3372.fits   3.42%         False
# 4                                  ../ngc3372.fits   3.39%         False
# 5                                  ../ngc3372.fits   2.92%         False
# 6                                  ../ngc3372.fits   2.43%         False
# 7                                  ../ngc3372.fits   2.37%         False
# 8                                  ../ngc3372.fits   2.35%         False
# 9                                  ../ngc3372.fits   2.26%         False
# 10                                 ../ngc3372.fits   2.05%         False
# 11                                 ../ngc3372.fits   1.93%         False
# 12                                 ../ngc3372.fits   1.90%         False
# 13                                 ../ngc3372.fits   1.80%         False
# 14                                 ../ngc3372.fits   1.79%         False
# 15                                 ../ngc3372.fits   1.76%         False
# 16                                 ../ngc3372.fits   1.73%         False
# 17                                 ../ngc3372.fits   1.70%         False
# 18                                 ../ngc3372.fits   1.63%         False
# 19                                 ../ngc3372.fits   1.55%         False
# 20                                 ../ngc3372.fits   1.53%         False
# 21                                 ../ngc3372.fits   1.52%         False
# 22                                 ../ngc3372.fits   1.49%         False
# 23                                 ../ngc3372.fits   1.37%         False
# 24                                 ../ngc3372.fits   1.34%         False
# 25                                 ../ngc3372.fits   1.31%         False
# 26                                 ../ngc3372.fits   1.14%         False
# 27                                 ../ngc3372.fits   1.13%         False
# 28       ../hdu0_2mass-atlas-000121s-k0720186.fits   0.67%         False
# 29                            ../ngc3372_area.fits   0.57%         False
# 30                                 ../ngc3372.fits   0.53%         False
# 31                            ../ngc3372_area.fits   0.44%         False
# 32                            ../ngc3372_area.fits   0.27%         False
# 33                            ../ngc3372_area.fits   0.26%         False
# 34       ../hdu0_2mass-atlas-000115s-k0640033.fits   0.25%         False
# 35                            ../ngc3372_area.fits   0.25%         False
# 36                            ../ngc3372_area.fits   0.23%         False
# 37       ../hdu0_2mass-atlas-000118s-k1130115.fits   0.20%         False
# 38       ../hdu0_2mass-atlas-000121s-k0730092.fits   0.14%         False
# 39       ../hdu0_2mass-atlas-000118s-k1140139.fits   0.14%         False
# 40                            ../ngc3372_area.fits   0.14%         False
# 41  ../hdu0_2mass-atlas-000118s-k1020186_area.fits   0.13%         False
#
#                                                                     \
#    is_fpp is_mpi is_posix is_read_only is_sequential is_write_only
# 0   False  False     True        False          True         False
# 1    True  False     True        False          True         False
# 2   False  False     True        False          True         False
# 3   False  False     True        False          True         False
# 4   False  False     True        False          True         False
# 5   False  False     True        False          True         False
# 6   False  False     True        False          True         False
# 7    True  False     True        False          True         False
# 8   False  False     True        False          True         False
# 9   False  False     True        False          True         False
# 10  False  False     True        False          True         False
# 11  False  False     True        False          True         False
# 12  False  False     True        False          True         False
# 13  False  False     True        False          True         False
# 14  False  False     True        False          True         False
# 15   True  False     True         True          True         False
# 16  False  False     True        False          True         False
# 17  False  False     True        False          True         False
# 18  False  False     True        False          True         False
# 19  False  False     True        False          True         False
# 20   True  False     True        False          True         False
# 21   True  False     True         True          True         False
# 22  False  False     True        False          True         False
# 23  False  False     True        False          True         False
# 24  False  False     True        False          True         False
# 25  False  False     True        False          True         False
# 26  False  False     True        False          True         False
# 27  False  False     True        False          True         False
# 28  False  False     True        False          True         False
# 29  False  False     True        False          True          True
# 30  False  False     True        False          True          True
# 31  False  False     True        False          True          True
# 32  False  False     True        False          True          True
# 33  False  False     True        False          True          True
# 34  False  False     True        False          True         False
# 35  False  False     True        False          True          True
# 36  False  False     True        False          True          True
# 37  False  False     True        False          True         False
# 38  False  False     True        False          True         False
# 39  False  False     True        False          True         False
# 40  False  False     True        False          True          True
# 41  False  False     True        False          True         False
#
#                       all                                                   r  \
#    md_io_ratio     agg_bw   agg_dur agg_size     ops files funcs ranks   xfer
# 0        0.02%  0.714GB/s  3.690958  2.635GB  153464     1     4     5   64KB
# 1        0.15%  4.745GB/s  1.873162  8.887GB   55454     1    10     1  256KB
# 2        0.03%  0.802GB/s  1.089136  0.874GB   66459     1     4     5   16KB
# 3        0.07%  0.865GB/s  1.019091  0.882GB   65863     1     4     5   16KB
# 4        0.13%  2.004GB/s  1.009439  2.023GB   50226     1     4     5   64KB
# 5        0.07%  1.231GB/s  0.868350  1.069GB  178024     2     4     5   16KB
# 6        0.04%  0.967GB/s  0.725000  0.701GB   68866     1     4     5   16KB
# 7        0.42%  0.974GB/s  0.704700  0.686GB   67167     1    10     1   16KB
# 8        0.11%  0.865GB/s  0.701066  0.606GB   68960     1     4     5   16KB
# 9        0.09%  0.806GB/s  0.673427  0.543GB  197957     1     4     5    4KB
# 10       0.08%  0.919GB/s  0.611575  0.562GB   68775     1     4     9   16KB
# 11       0.04%  0.963GB/s  0.573805  0.552GB   63500     1     4     5   16KB
# 12       0.06%  0.633GB/s  0.566773  0.359GB  131103     1     4     5    4KB
# 13       0.08%  0.843GB/s  0.535537  0.452GB  164991     1     4     5    4KB
# 14       0.12%  0.809GB/s  0.532708  0.431GB  157451     1     4     5    4KB
# 15       0.05%  1.047GB/s  0.523743  0.548GB   63741     1     3     1   16KB
# 16       0.06%  0.934GB/s  0.515410  0.482GB  175887     1     4     5    4KB
# 17       0.16%  0.908GB/s  0.507184  0.461GB  165166     1     4     9    4KB
# 18       0.19%  0.895GB/s  0.484346  0.434GB  158447     1     4     5    4KB
# 19       0.11%  0.724GB/s  0.461640  0.334GB  122076     1     4     5    4KB
# 20       0.44%  0.898GB/s  0.455543  0.409GB  151724     1    10     1    4KB
# 21       0.06%  0.899GB/s  0.452748  0.407GB  151739     1     3     1    4KB
# 22       0.06%  0.828GB/s  0.444467  0.368GB  134446     1     4     5    4KB
# 23      23.08%  0.680GB/s  0.406641  0.277GB   17796     1    10     5   64KB
# 24       0.11%  0.845GB/s  0.398638  0.337GB  122982     1     4     5    4KB
# 25       0.06%  0.830GB/s  0.390904  0.324GB  118570     1     4     5    4KB
# 26       0.16%  0.867GB/s  0.340026  0.295GB  107643     1     4     5    4KB
# 27       0.12%  0.982GB/s  0.337688  0.332GB   18298     1     4     5   64KB
# 28       0.66%  0.039GB/s  0.198844  0.008GB    2906     1     6     4    4KB
# 29       0.06%  0.510GB/s  0.171093  0.087GB    5084     1     3     4   <4KB
# 30       0.37%  3.003GB/s  0.158803  0.477GB    5292     1     3     4   <4KB
# 31       0.33%  3.639GB/s  0.131082  0.477GB    5292     1     3     4   <4KB
# 32       0.11%  0.219GB/s  0.081812  0.018GB    2288     1     3     4   <4KB
# 33       0.39%  0.459GB/s  0.078356  0.036GB    4416     1     3     8   <4KB
# 34       0.52%  0.054GB/s  0.074825  0.004GB    1528     1     6     2    4KB
# 35      93.71%  0.154GB/s  0.073817  0.011GB     756     1     8     5   <4KB
# 36       0.60%  0.977GB/s  0.068449  0.067GB    1668     1     3     4   <4KB
# 37       0.82%  0.130GB/s  0.060151  0.008GB    2932     1     6     4    4KB
# 38       3.41%  0.183GB/s  0.042504  0.008GB    2922     1     6     4    4KB
# 39       2.32%  0.183GB/s  0.042043  0.008GB    2895     1     6     4    4KB
# 40       0.54%  0.721GB/s  0.040468  0.029GB    2188     1     3     4   <4KB
# 41       0.90%  0.101GB/s  0.040043  0.004GB    1521     1     5     2    4KB
#
#         w
#      xfer
# 0    64KB
# 1   256KB
# 2    16KB
# 3    16KB
# 4    64KB
# 5    16KB
# 6    16KB
# 7    16KB
# 8    16KB
# 9    16KB
# 10   16KB
# 11   16KB
# 12   16KB
# 13   16KB
# 14   16KB
# 15   <4KB
# 16   16KB
# 17   16KB
# 18   16KB
# 19   16KB
# 20   16KB
# 21   <4KB
# 22   16KB
# 23   64KB
# 24   16KB
# 25   16KB
# 26   16KB
# 27   64KB
# 28    4KB
# 29   64KB
# 30  256KB
# 31  256KB
# 32   16KB
# 33   16KB
# 34    4KB
# 35   64KB
# 36   64KB
# 37    4KB
# 38    4KB
# 39    4KB
# 40   16KB
# 41    4KB

# %%
llc_proc_id_agg_bw_file = '../vani/.digio/1670872087_montage/llc-all-proc_id-agg_bw.json'
llc_proc_id_agg_bw_df = llc_to_df(json_file=llc_proc_id_agg_bw_file, name='proc > agg_bw', index_column='rank', per_column='per_agg_bw')
llc_proc_id_agg_bw_df
# Out:
#   proc > agg_bw                                                           \
#            rank      % is_collective is_fpp is_mpi is_posix is_read_only
# 0           [0]  0.00%         False   True  False     True        False
# 1           [0]  0.00%         False   True  False     True        False
# 2           [0]  0.00%         False   True  False     True        False
# 3           [0]  0.00%         False   True  False     True        False
# 4           [0]  0.00%         False   True  False     True        False
#
#                                                  all                         \
#   is_sequential is_write_only md_io_ratio     agg_bw   agg_dur agg_size ops
# 0         False          True      99.81%  0.000GB/s  0.004661  0.000GB  28
# 1         False          True      99.28%  0.000GB/s  0.001118  0.000GB  28
# 2         False          True      99.00%  0.000GB/s  0.000903  0.000GB  28
# 3         False          True      99.03%  0.000GB/s  0.000900  0.000GB  28
# 4         False          True      98.66%  0.000GB/s  0.000837  0.000GB  28
#
#                         r    w
#   files funcs ranks  xfer xfer
# 0     2     6     1  <4KB  4KB
# 1     2     6     1  <4KB  4KB
# 2     2     6     1  <4KB  4KB
# 3     2     6     1  <4KB  4KB
# 4     2     6     1  <4KB  4KB

# %%
llc_proc_id_agg_dur_file = '../vani/.digio/1670872087_montage/llc-all-proc_id-agg_dur.json'
llc_proc_id_agg_dur_df = llc_to_df(json_file=llc_proc_id_agg_dur_file, name='proc > agg_dur', index_column='rank', per_column='per_agg_dur')
llc_proc_id_agg_dur_df
# Out:
#     proc > agg_dur                                                            \
#               rank       % is_collective is_fpp is_mpi is_posix is_read_only
# 0              [0]  10.08%         False   True  False     True        False
# 1              [0]   5.07%         False   True  False     True        False
# 2              [0]   2.89%         False   True  False     True        False
# 3              [0]   2.78%         False   True  False     True        False
# 4              [0]   2.66%         False   True  False     True        False
# ..             ...     ...           ...    ...    ...      ...          ...
# 118           [22]   0.14%         False  False  False     True        False
# 119           [21]   0.14%         False  False  False     True        False
# 120           [20]   0.14%         False  False  False     True        False
# 121           [22]   0.14%         False  False  False     True        False
# 122           [22]   0.14%         False  False  False     True        False
#
#                                                    all                     \
#     is_sequential is_write_only md_io_ratio     agg_bw   agg_dur agg_size
# 0            True         False       0.08%  0.712GB/s  3.585443  2.551GB
# 1            True         False       0.12%  4.888GB/s  1.803386  8.815GB
# 2            True         False       0.22%  0.827GB/s  1.026742  0.849GB
# 3            True         False       0.60%  0.867GB/s  0.987185  0.856GB
# 4            True         False       0.25%  2.070GB/s  0.946837  1.960GB
# ..            ...           ...         ...        ...       ...      ...
# 118         False         False       5.78%  0.270GB/s  0.051389  0.014GB
# 119         False         False       8.99%  0.242GB/s  0.050911  0.012GB
# 120         False         False       7.89%  0.149GB/s  0.049738  0.007GB
# 121         False         False       6.88%  0.180GB/s  0.049582  0.009GB
# 122         False         False       5.69%  0.154GB/s  0.049550  0.008GB
#
#                                    r     w
#         ops files funcs ranks   xfer  xfer
# 0    148383     2     4     1   64KB   4MB
# 1     54912     2     4     1  256KB   4MB
# 2     64254     2     4     1   16KB  16MB
# 3     63678     2     4     1   16KB   4MB
# 4     48561     2     4     1   64KB  16MB
# ..      ...   ...   ...   ...    ...   ...
# 118    2844     8     6     1    4KB  16KB
# 119    3254     8     6     1    4KB  16KB
# 120    1416     6     6     1    4KB  16KB
# 121    2094     8     6     1    4KB  16KB
# 122    1216     6     6     1    4KB  16KB
#
# [123 rows x 19 columns]

# %%
llc_tmid_agg_bw_file = '../vani/.digio/1670872087_montage/llc-all-tmid-agg_bw.json'
llc_tmid_agg_bw_df = llc_to_df(json_file=llc_tmid_agg_bw_file, name='time > agg_bw', index_column='time', per_column='per_agg_bw')
llc_tmid_agg_bw_df
# Out:
#   time > agg_bw                                                           \
#            time      % is_collective is_fpp is_mpi is_posix is_read_only
# 0     0.00-0.17  0.01%         False  False  False     True        False
# 1     2.57-2.74  0.03%         False  False  False     True        False
# 2   24.13-24.30  0.07%         False  False  False     True        False
# 3   22.25-22.42  0.07%         False  False  False     True        False
# 4   22.76-22.93  0.07%         False  False  False     True        False
#
#                                                  all                     \
#   is_sequential is_write_only md_io_ratio     agg_bw   agg_dur agg_size
# 0         False         False       7.83%  0.159GB/s  0.104134  0.017GB
# 1         False         False       0.44%  0.381GB/s  1.376926  0.524GB
# 2          True         False      32.60%  0.867GB/s  0.017502  0.015GB
# 3          True         False       8.19%  0.867GB/s  0.013905  0.012GB
# 4         False         False       7.73%  0.909GB/s  0.016273  0.015GB
#
#                                r    w
#      ops files funcs ranks  xfer xfer
# 0  15546   937     8    13  16KB  4KB
# 1  70175   216    11     1  16KB  4KB
# 2   4228     6     6     1   4KB  4KB
# 3   4508     4     6     1   4KB  4KB
# 4   5311     5     8     1  64KB  4KB

# %%
llc_tmid_agg_dur_file = '../vani/.digio/1670872087_montage/llc-all-tmid-agg_dur.json'
llc_tmid_agg_dur_df = llc_to_df(json_file=llc_tmid_agg_dur_file, name='time > agg_dur', index_column='time', per_column='per_agg_dur')
llc_tmid_agg_dur_df
# Out:
#     time > agg_dur                                                            \
#               time       % is_collective is_fpp is_mpi is_posix is_read_only
# 0        2.57-2.74  17.32%         False  False  False     True        False
# 1        0.51-0.68   5.68%         False  False  False     True        False
# 2        0.17-0.34   3.88%         False  False  False     True        False
# 3        0.68-0.86   3.50%         False  False  False     True        False
# 4        3.42-3.59   2.59%         False  False  False     True        False
# ..             ...     ...           ...    ...    ...      ...          ...
# 124    14.72-14.89   0.17%         False  False  False     True        False
# 125    21.57-21.74   0.17%         False   True  False     True         True
# 126    13.52-13.69   0.15%         False  False  False     True        False
# 127    13.69-13.86   0.10%         False  False  False     True        False
# 128    17.97-18.14   0.10%         False   True  False     True         True
#
#                                                    all                     \
#     is_sequential is_write_only md_io_ratio     agg_bw   agg_dur agg_size
# 0           False         False       0.44%  0.381GB/s  1.376926  0.524GB
# 1           False         False      20.44%  4.929GB/s  0.451566  2.226GB
# 2           False         False       1.69%  2.813GB/s  0.308806  0.869GB
# 3            True         False      24.69%  6.448GB/s  0.278646  1.797GB
# 4           False         False       0.64%  1.908GB/s  0.205753  0.393GB
# ..            ...           ...         ...        ...       ...      ...
# 124         False         False       4.00%  2.950GB/s  0.013243  0.039GB
# 125          True         False       0.00%  1.367GB/s  0.013238  0.018GB
# 126         False         False       4.55%  1.586GB/s  0.011715  0.019GB
# 127          True         False      40.27%  2.650GB/s  0.007751  0.021GB
# 128          True         False       0.00%  1.384GB/s  0.007705  0.011GB
#
#                                   r     w
#         ops files funcs ranks  xfer  xfer
# 0     70175   216    11     1  16KB   4KB
# 1    395083   160     8    13  16KB  64KB
# 2    147355   391    15    13  16KB  16KB
# 3    323866   116     4    13  16KB  16KB
# 4     67306    47     8     4  16KB   4KB
# ..      ...   ...   ...   ...   ...   ...
# 124    3951    12     7     1  64KB   4KB
# 125    1054     1     1     1  64KB  <4KB
# 126    1164     8     7     1  64KB   4KB
# 127     275     7     4     1  64KB   4MB
# 128     621     1     1     1  64KB  <4KB
#
# [129 rows x 19 columns]
