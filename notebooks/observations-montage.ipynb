# %%
# %run observations.ipynb

# %%
llc_file_id_agg_bw_file = '../vani/.digio/1670226601_montage/llc-all-file_id-agg_bw.json'
llc_file_id_agg_bw_df = llc_to_df(json_file=llc_file_id_agg_bw_file, name='file > agg_bw', index_column='file', per_column='per_agg_bw')
llc_file_id_agg_bw_df
# Out:
#                             file > agg_bw                                     \
#                                      file      % is_collective is_fpp is_mpi
# 0                         ../ngc3372.fits  0.16%         False   True  False
# 1    ../2mass-atlas-000118s-k1150080.fits  0.15%         False   True  False
# 2    ../2mass-atlas-000118s-k1090068.fits  0.15%         False   True  False
# 3    ../2mass-atlas-000118s-k0850115.fits  0.15%         False   True  False
# 4    ../2mass-atlas-000115s-k0520033.fits  0.15%         False   True  False
# ..                                    ...    ...           ...    ...    ...
# 205  ../2mass-atlas-000118s-k1000115.fits  0.14%         False   True  False
# 206  ../2mass-atlas-000121s-k0730056.fits  0.14%         False   True  False
# 207  ../2mass-atlas-000118s-k0830221.fits  0.14%         False   True  False
# 208  ../2mass-atlas-000118s-k1020044.fits  0.14%         False   True  False
# ...

# %%
llc_file_id_agg_dur_file = '../vani/.digio/1670226601_montage/llc-all-file_id-agg_dur.json'
llc_file_id_agg_dur_df = llc_to_df(json_file=llc_file_id_agg_dur_file, name='file > agg_dur', index_column='file', per_column='per_agg_dur')
llc_file_id_agg_dur_df
# Out:
#                                     file > agg_dur                        \
#                                               file       % is_collective
# 0                                  ../ngc3372.fits  12.73%         False
# 1                                  ../ngc3372.fits    nan%         False
# 2                                  ../ngc3372.fits   3.76%         False
# 3                                  ../ngc3372.fits   3.52%         False
# 4                                  ../ngc3372.fits   3.49%         False
# 5                                  ../ngc3372.fits   3.00%         False
# 6                                  ../ngc3372.fits   2.50%         False
# 7                                  ../ngc3372.fits   2.44%         False
# 8                                  ../ngc3372.fits   2.42%         False
# 9                                  ../ngc3372.fits   2.03%         False
# 10                                 ../ngc3372.fits   1.97%         False
# ...

# %%
llc_proc_id_agg_bw_file = '../vani/.digio/1670226601_montage/llc-all-proc_id-agg_bw.json'
llc_proc_id_agg_bw_df = llc_to_df(json_file=llc_proc_id_agg_bw_file, name='proc > agg_bw', index_column='rank', per_column='per_agg_bw')
llc_proc_id_agg_bw_df
# Out:
#     proc > agg_bw                                                           \
#              rank      % is_collective is_fpp is_mpi is_posix is_read_only
# 0             [0]  3.63%         False   True  False     True        False
# 1             [0]  1.69%         False  False  False     True        False
# 2             [0]  1.66%         False  False  False     True        False
# 3             [0]  1.66%         False  False  False     True        False
# 4             [0]  1.61%         False  False  False     True        False
# ..            ...    ...           ...    ...    ...      ...          ...
# 130          [23]  0.15%         False  False  False     True        False
# 131          [25]  0.15%         False  False  False     True        False
# 132          [21]  0.14%         False  False  False     True        False
# 133          [20]  0.13%         False  False  False     True        False
# ...

# %%
llc_proc_id_agg_dur_file = '../vani/.digio/1670226601_montage/llc-all-proc_id-agg_dur.json'
llc_proc_id_agg_dur_df = llc_to_df(json_file=llc_proc_id_agg_dur_file, name='proc > agg_dur', index_column='rank', per_column='per_agg_dur')
llc_proc_id_agg_dur_df
# Out:
#    proc > agg_dur                                                          \
#              rank     % is_collective is_fpp is_mpi is_posix is_read_only
# 0             [0]  nan%         False   True  False     True        False
# 1             [0]  nan%         False   True  False     True        False
# 2             [0]  nan%         False   True  False     True        False
# 3             [0]  nan%         False   True  False     True        False
# 4             [0]  nan%         False   True  False     True        False
# ..            ...   ...           ...    ...    ...      ...          ...
# 95            [0]  nan%         False  False  False     True        False
# 96           [20]  nan%         False  False  False     True        False
# 97           [22]  nan%         False  False  False     True        False
# 98           [21]  nan%         False  False  False     True        False
# 99           [22]  nan%         False  False  False     True        False
#
# ...

# %%
llc_tmid_agg_bw_file = '../vani/.digio/1670226601_montage/llc-all-tmid-agg_bw.json'
llc_tmid_agg_bw_df = llc_to_df(json_file=llc_tmid_agg_bw_file, name='time > agg_bw', index_column='time', per_column='per_agg_bw')
llc_tmid_agg_bw_df
# Out:
#     time > agg_bw                                                           \
#              time      % is_collective is_fpp is_mpi is_posix is_read_only
# 0       1.20-1.37  1.37%         False  False  False     True        False
# 1       0.86-1.03  0.96%         False  False  False     True        False
# 2       9.41-9.58  0.94%         False  False  False     True        False
# 3       0.34-0.51  0.87%         False  False  False     True        False
# 4       6.33-6.50  0.85%         False  False  False     True         True
# ..            ...    ...           ...    ...    ...      ...          ...
# 215   10.10-10.27  0.15%         False  False  False     True         True
# 216   17.12-17.29  0.14%         False  False  False     True        False
# 217   15.75-15.92  0.14%         False  False  False     True        False
# 218   19.00-19.17  0.14%         False  False  False     True        False
# ...

# %%
llc_tmid_agg_dur_file = '../vani/.digio/1670226601_montage/llc-all-tmid-agg_dur.json'
llc_tmid_agg_dur_df = llc_to_df(json_file=llc_tmid_agg_dur_file, name='time > agg_dur', index_column='time', per_column='per_agg_dur')
llc_tmid_agg_dur_df
# Out:
#     time > agg_dur                                                            \
#               time       % is_collective is_fpp is_mpi is_posix is_read_only
# 0        2.57-2.74  17.98%         False  False  False     True        False
# 1        0.51-0.68    nan%         False  False  False     True        False
# 2        0.68-0.86    nan%         False  False  False     True        False
# 3        0.17-0.34    nan%         False  False  False     True        False
# 4        1.37-1.54    nan%         False  False  False     True        False
# ..             ...     ...           ...    ...    ...      ...          ...
# 124    14.72-14.89    nan%         False  False  False     True        False
# 125    21.57-21.74   0.17%         False   True  False     True         True
# 126    13.52-13.69   0.15%         False  False  False     True        False
# 127    13.69-13.86    nan%         False  False  False     True        False
# ...
